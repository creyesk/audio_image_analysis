# %% [markdown]
# # Modelos probabilísticos de ortografía
#
# ## Ortografía: Dada una secuencia de letras de una palabra mal escrita producir una lista ordenada de palabras posibles escritas de manera correcta
#
# ### Aplicaciones: Chats, procesamiento de textos, OCR.
#
# ### 80% de errores con el teclado se debe a errores de un solo caracter en una de las siguientes formas:
#  - Inserción:          * carro -> carreo*
#  - Supresión:        * carro -> caro*
#  - Substitución:    * carro -> carto*
#  - Transposición: * carro -> caror*

# %%
letters    = "abcdefghijklmnopqrstuvwxyz\'"
def edits1(word):
    "All edits that are one edit away from `word`."
    splits     = [(word[:i], word[i:])    for i in range(len(word) + 1)]
    deletes    = [L + R[1:]               for L, R in splits if R]
    transposes = [L + R[1] + R[0] + R[2:] for L, R in splits if len(R)>1]
    replaces   = [L + c + R[1:]           for L, R in splits if R for c in letters]
    inserts    = [L + c + R               for L, R in splits for c in letters]
    return set(deletes + transposes + replaces + inserts)

def known(words):
    return set(w for w in words if w in WORDS)

# %% [markdown]
# ### Vocabulario

# %%
import re
from collections import Counter

with open('data/big.txt', 'r') as f:
    corpus = f.read()

def words(text): return re.findall(r'\w+', text.lower())

WORDS = Counter(words(corpus))

# %% [markdown]
# ### Para una palabra dada podemos calcular todas las palabras que se encuentras a distancia uno de ella.

# %%
word = 'something'
print(edits1(word), end=' '), len(edits1(word)), known(edits1('somthing'))
# Out:
# {'somethzing', 'somethins', 'somethinw', 'somesthing', 'somethking', 'somsething', 'somethuing', 'somethirg', 'somethiug', 'svomething', 'romething', 'bomething', 'somethingq', 'sodething', 'eomething', 'sosmething', 'syomething', 'somevthing', 'soxething', 'somethieng', 'msomething', 'somejthing', 'somfething', 'somethinig', 'somiething', 'solmething', 'somenthing', "som'thing", 'somekhing', 'sjomething', 'somethifng', 'sometfing', 'sometsing', 'homething', 'somdething', 'sometching', 'someching', 'sometqing', 'somedthing', 'sometjhing', 'lomething', 'somethibg', 'sometging', 'somethincg', 'somethinag', 'tsomething', 'somwething', 'somedhing', 'somthing', 'ssmething', 'somethihng', 'someothing', 'somethink', 'sfomething', 'somethinzg', 'somyething', 'psomething', 'sogmething', 'rsomething', 'sowmething', 'soqething', 'jsomething', 'yomething', 'sombthing', 'sompething', 'somethingv', 'somethixg', 'somethinng', 'dsomething', 'somethnng', 'somethihg', 'oomething', 'somethingg', 'somethinyg', 'sometning', 'somethiyng', 'somethingb', 'somethiog', 'somethinxg', 'sometuing', 'somethinge', 'scomething', 'somethindg', 'semething', 'someahing', 'somnething', 'sometzhing', 'somethimng', 'slmething', 'sonmething', 'sozmething', 'somerthing', 'sometfhing', 'sofething', 'somzthing', 'sjmething', 'smething', 'sojmething', 'somuething', 'gsomething', 'somethinwg', 'hsomething', "someth'ng", 'osomething', 'somethingw', 'shmething', 'soeething', 'somethning', 'somcthing', 'scmething', 'siomething', 'somethinqg', 'sokething', "somethin'g", 'sometlhing', 'someohing', 'somtthing', 'sometrhing', 'sotmething', 'isomething', 'somethtng', 'swmething', 'someghing', 'somethiny', 'somethingp', 'somethjing', 'comething', 'somecthing', 'suomething', 'somethinga', 'somjthing', 'somethingy', 'somethieg', 'sopmething', 'sometshing', 'someting', 'soyething', 'somethingo', 'sometheng', 'somethini', "something'", 'sovmething', 'somethiag', 'sohething', 'somethinc', 'somethimg', 'somethinm', 'tomething', 'socething', 'wsomething', 'something', 'somehhing', 'somethipng', "someth'ing", 'somxething', "some'hing", 'somethinr', 'somethizg', 'somethrng', 'somything', 'sometding', 'sometheing', 'somethig', 'sometting', "somethin'", 'somehthing', 'aomething', 'sogething', 'somethind', 'sobmething', 'domething', 'sometking', 'sometling', 'someqthing', 'somethinl', 'somethinp', 'snomething', 'somqething', 'stmething', 'somethingt', 'socmething', "somethi'g", 'somethinhg', 'somethting', 'somethinb', 'somrthing', 'somethinbg', 'sometohing', 'somexhing', 'soqmething', 'somethitng', 'somoething', 'uomething', 'sometxhing', 'soemthing', 'someuthing', 'usomething', 'somuthing', 'someuhing', 'sometming', 'someihing', 'xsomething', 'sompthing', 'seomething', 'swomething', 'somkething', 'samething', 'ssomething', 'somethinjg', 'sgomething', "so'mething", 'somethinpg', 'sqmething', "so'ething", 'womething', 'soymething', 'spomething', 'sometmhing', 'sorething', 'somerhing', 'somethingr', 'solething', 'sodmething', 'somzething', 'somethfng', 'somefhing', 'sometvhing', 'soimething', 'shomething', 'sommthing', 'somlething', 'somethinu', "s'mething", 'somethinx', 'somethjng', 'sometping', 'somethinog', 'somothing', 'someathing', 'somethinsg', 'somezhing', 'somethhing', 'sbmething', 'somethivng', 'somlthing', 'somethoing', 'somethsing', 'somethikng', 'simething', 'somethino', 'somethina', 'sbomething', "some'thing", 'sovething', 'somethiqg', 'somethicg', "'omething", 'somethbng', 'somcething', 'somethlng', 'zomething', 'somethidg', 'somethign', 'somethiwg', 'somethilg', 'somepthing', 'somdthing', "s'omething", 'someething', 'somethsng', 'soiething', 'somethingn', 'somethigg', 'somethiqng', 'somehting', 'someshing', 'sfmething', 'somethong', 'somethingd', 'somethingc', 'somethiig', 'somethiing', 'somaething', 'somethinf', 'somemhing', 'sozething', 'somethijg', 'somethring', 'somethiang', 'asomething', 'sometnhing', 'somethirng', 'somethiyg', 'somethinv', 'somethaing', 'somethkng', 'some ...
# (None, 513, {'something', 'soothing'})

# %% [markdown]
# ### La gran mayoria de errores están a una distancia menor o igual a 2. Aproximadamente el 98%

# %%
word = 'somemme'
def edits2(word):
    return set(e2 for e1 in edits1(word) for e2 in edits1(e1))

# %%
len(edits2(word)), len(known(edits2(word))), known(edits2(word))
# Out:
# (74325, 2, {'someone', 'sometime'})

# %% [markdown]
# ### Los errores más comunes para los mecanógrafos son los de substitución por letras adyacentes en el teclado (59%).
#
# ### Errores cognitivos: Substitución de una sequencia de letras por otra fonéticamente equivalente,
# - *cerrar -> serrar*
#
# ### Errores de OCR:
# - **Texto**: The quick brown fox jumps over the lazy dog.
# - **Reconocido**: The q~ck brown foxjurnps ovcr tb l azy dog.
#
# ## Tarea:
# -**Reconocimiento de voz** - Dada la pronunciación de una palabra se desea encontrar la palabra verdadera
# -**Corrección de ortografía**- Dada una palabra mal escrita encontrar la palabra verdadera
#
#
# ## Inferencia Bayesiana:
# - P(palabra|obsevación) = : $P(w|O)$
# - El objetivo es encontrar la palabra más probable dada la observación:
# \begin{equation} \text{argmax}_{w\in V} P(w\,|\,O)
# \end{equation}
# - Teorema de Bayes:
# \begin{equation} P(x\,|\,y) = \frac{P(y\,|\,x)P(x)}{P(y)} \end{equation}
# - El problema se transforma en el siguiente:
# \begin{equation} \hat{w} =  \text{argmax}_{w\in V} \frac{P(O\,|\,w)P(w)}{P(O)} \end{equation}
# - Las probabilidades del lado derecho son por lo general más fáciles de calcular. En este caso $P(w)$ es la frecuencia relativa de la palabra en el corpus. P(O|w) se calcula de acuerdo al modelo en nuestro caso un canal ruidoso. $P(O)$, la probabilidad de una observación es difícil de calcular, la bueno es que no hay que hacerlo.
# \begin{equation}
# \hat{w} =  \text{argmax}_{w\in V} \frac{P(O\,|\,w)P(w)}{P(O)} = \text{argmax}_{w\in V} P(O\,|\,w)P(w)
# \end{equation}
# - $P(w)$ se llama la distribución previa y $P(O\,|\,w)$ es la verosimilitud de la observación.
#
#
# ## Modelo de canal ruidoso:
# - Se parte de la palabra correcta y se deforma para encontrar la palabra con errores. Con el análisis bayesiano se intenta encontrar la palabra original.
# - Un primer modelo: se asume que la palabra original difiera de la mal escrita en solo una inserción, supresión, substitución o transposición.
# ![title](tabla_errores_ortografia.png)
#
# $$\hat{c} = \text{argmax} P(e\,|\,c)P(c)$$
#
# - $P(c)$ se calcula como la frecuencia de la palabra en el corpus.
# $$P(c) = \frac{C(c) + 0.5}{N + 0.5V},$$ Donde $N$ es la cantidad de palabras en el corpus y $V$ es la cantidad de palabras en el vocabulario.
# - $P(e\,|\,c)$ depende de muchos factores, por ejemplo de la persona que esta escribiendo.
#
# - Una forma sencilla se estimar $P(e\,|\,c)$ es utilizando una matriz de confusión para cada tipo de error.

# %% [markdown]
# ### P: frecuencia relativa de las palabras

# %%
def P(word, N=sum(WORDS.values())):
    return (WORDS[word]+0.5) / (N + 0.5*len(WORDS))

# %%
len(WORDS), WORDS.most_common(n=10), P('the')
# Out:
# (32198,
#  [('the', 79809),
#   ('of', 40024),
#   ('and', 38312),
#   ('to', 28765),
#   ('in', 22023),
#   ('a', 21124),
#   ('that', 12512),
#   ('he', 12401),
#   ('was', 11410),
#   ('it', 10681)],
#  0.07052277844345241)

# %% [markdown]
# ### Importar base de datos de errores

# %%
mispelled_dict = {}
repeat_re = re.compile(r'(.+)\*(\d+)')
with open("data/spell-errors.txt") as f:
    for line in f:
        (key, val) = line.split(':')
        val = re.sub(pattern= r'\n| ',repl='',string=val)
        val = val.split(",")
        val_new = list()
        for word in val:
            word = word.lower()
            if repeat_re.match(word):                
                repeated = repeat_re.findall(word)[0]
                val_new = val_new + [repeated[0]]*int(repeated[1])
            else:
                val_new = val_new + [word]
        mispelled_dict[key.lower()] = val_new

# %%
mispelled_dict
# Out:
# {'raining': ['rainning', 'raning'],
#  'writings': ['writtings'],
#  'disparagingly': ['disparingly'],
#  'yellow': ['yello'],
#  'four': ['forer',
#   'fours',
#   'fuore',
#   'fore',
#   'fore',
#   'fore',
#   'fore',
#   'fore',
#   'for',
#   'for',
#   'for',
#   'for'],
#  'woods': ['woodes'],
#  'hanging': ['haing'],
#  'aggression': ['agression'],
#  'looking': ['loking',
#   'begining',
#   'luing',
#   'look',
#   'look',
#   'locking',
#   'lucking',
#   'louk',
#   'looing',
#   'lookin',
#   'liking'],
#  'eligible': ['eligble', 'elegable', 'eligable'],
#  'electricity': ['electrisity', 'electricty', 'electricty', 'electrizity'],
#  'scold': ['schold', 'skold'],
#  'adaptable': ['adabtable'],
#  'caned': ['canned', 'cained'],
#  'immature': ['imature'],
#  "shouldn't": ['shoudln', 'shouldnt'],
#  'swivel': ['swival'],
#  'appropriation': ['apropriation'],
#  'fur': ['furr', 'fer'],
#  'stabbed': ['stabed'],
#  'southwold': ['suothwode'],
#  'disturb': ['distrebe', 'desturb'],
#  'recollections': ['reclections', 'recolections'],
#  'prize': ['prise', 'prizer'],
#  'wednesday': ['wendsay', 'wensday', 'wedensday', 'wensday', 'wdendsdy'],
#  'succession': ['sucession', 'sucesion', 'succesion'],
#  'straight': ['strate', 'strait', 'staidght', 'stright', 'stright'],
#  'guardsmen': ['gards_men'],
#  'incremented': ['increented'],
#  'bacon': ['backen', 'baken'],
#  'pulse': ['pluse'],
#  'elegant': ['elagent', 'elligit'],
#  'second': ['secand', 'sexeon', 'secund', 'seconnd', 'seond', 'sekon'],
#  'jamjar': ['jam_jar'],
#  'sailed': ['saled', 'saild'],
#  'blouse': ['boludes'],
#  'thunder': ['thounder'],
#  'cooking': ['coking', 'chocking', 'kooking', 'cocking'],
#  'fossil': ['fosscil'],
#  'increasing': ['incased',
#   'ingreesh_this',
#   'incresing',
#   'incriosing',
#   'increacing',
#   'incressing',
#   'increcing',
#   'ingeker',
#   'incrsin',
#   'inceasing',
#   'inceing',
#   'increase',
#   'insest',
#   'ingcresing',
#   'incuiseing',
#   'enchres',
#   'intheris',
#   'incesing',
#   'encreing',
#   'increesing',
#   'crace',
#   'encrising',
#   'increaseng',
#   'encressing',
#   'in_cresing',
#   'incrising',
#   'incersinges',
#   'changing',
#   'incesting',
#   'encreasing',
#   'crissing',
#   'incriasing',
#   'incsin',
#   'incing',
#   'increaseing',
#   'ingesing',
#   'imceasing',
#   'incristing',
#   'engressing',
#   'ingresin',
#   'incrase',
#   'encash'],
#  'hero': ['heroe'],
#  'dahl': ['dael'],
#  'reporter': ['repoter',
#   'rebarter',
#   'reportor',
#   'reproter',
#   'reoporter',
#   'repoted',
#   'reporet',
#   'peportery'],
#  'interrupting': ['interupting'],
#  'here': ['hiar',
#   'hare',
#   'hir',
#   'hair',
#   'haiw',
#   'liet',
#   'hreb',
#   'hah',
#   'her',
#   'hes',
#   'hiyr',
#   'there',
#   'three',
#   'hay',
#   'hea',
#   'herre',
#   'har',
#   'werr',
#   'head',
#   'heere',
#   'hera',
#   'heir',
#   'herd',
#   'heat',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'hear',
#   'handr',
#   'he',
#   'heer',
#   'hree',
#   'hire',
#   'thehe',
#   'hon',
#   'eate',
#   'poit'],
#  'atoms': ['atom'],
#  'tape-recorded': ['tape_recorded'],
#  'shriek': ['shreik'],
#  'substance': ['substace'],
#  'elaborate': ['elaberate'],
#  'climbed': ['climb', 'climed', 'cimed'],
#  'reports': ['reoprts'],
#  'controversy': ['contervercing',
#   'contervercuy',
#   'consonerse',
#   'counteversy',
#   'contravercy',
#   'contronversey',
#   'contiversey',
#   'countirversay',
#   'countrovesy',
#   'counterversing',
#   'comsversiary',
#   'controversave',
#   'contevesy',
#   'controveries',
#   'controversey',
#   'controvercy',
#   'controvercy',
#   'contraversally',
#   'conteversy',
#   'comtevercy',
#   'controversaries',
#   'countufersey',
#   'controvarsey',
#   'conqouversing',
#   'contriversy',
#   'contraversey',
#   'controvesey',
#   'contraverse',
#   'countroversy',
#   'contraversy',
#   'contraversy',
#   'constroversy',
#   'contruevency',
#   'connesary',
#   'contavercy',
#   'conversity',
#   'contretearsing',
#   'controvery',
#   'contrevy',
#   'controvsary',
#   'contiuvisy',
#   'controvese',
#   'contronersery',
#   'controvorsey',
#   'contravorsy',
#   'countrevercy',
#   'controvvesity',
#   'conterversy',
#   'conterverisy',
#   'contriversey',
#   'conterversty',
#   'contreversey',
#   'combtrovesy',
#   'conversey',
#   'contterversy',
#   'conturvesy',
#   'contrvercy',
#   'controvesy',
#   'coutueversy',
#   'controsory',
#   'contrefercing',
#   'counterners',
#   'controvercey',
#   'contowversie',
#   'controversay',
#   'conversation',
#   'controversary',
#   'contraversery',
#   'contreversy',
#   'controversie',
#   'contriverse',
#   'controversing',
#   'conterversay',
#   'contrusy'],
#  'etiology': ['eitiology'],
#  'snowing': ['showing'],
#  'military': ['millitary', 'milatary', 'militery'],
#  'cancellation': ['canselation',
#   'cassilation',
#   'canncelation',
#   'cancalation',
#   'consulation',
#   'cancelatin',
#   'canelation',
#   'cansallation',
#   'cansellation',
#   'cansilation',
#   'cancallation',
#   'canacellation',
#   'cannsulation',
#   'cansaltion',
#   'cancolateon',
#   'cansulation',
#   'consalation',
#   'canselution',
#   'cancilliation',
#   'canslation',
#   'cancillation',
#   'cancolation',
#   'cansalation',
#   'cancialation',
#   'cancatation',
#   'cancilation',
#   'canclation',
#   'cansolitation',
#   'cansolation',
#   'cancealation',
#   'cancilion',
#   'cancelation',
#   'chancelation',
#   'cansclitation'],
#  'criticism': ['criticisim',
#   'critizeation',
#   'criticizem',
#   'coritisumn',
#   'critisicsm',
#   'criticisam',
#   'critisizem',
#   'critisium',
#   'critizition',
#   'critisisem',
#   'crisisem',
#   'critiscism',
#   'critisisum',
#   'critigism',
#   'critisum',
#   'critizim',
#   'certsemus',
#   'griticism',
#   'critizm',
#   'critizesum',
#   'cretism',
#   'crisizum',
#   'critisima',
#   'critizam',
#   'critisizum',
#   'critisiem',
#   'criticisiom',
#   'critisim',
#   'critizizem',
#   'critisizm',
#   'critisism',
#   'critisism',
#   'critisiciam',
#   'crictism',
#   'critizium',
#   'critisicm',
#   'crittissisam',
#   'criticiz',
#   'criticisium',
#   'critisyum',
#   'critisicem',
#   'critissam',
#   'criticiam',
#   'citisum',
#   'critizom',
#   'critiszm',
#   'criticise',
#   'critisisim',
#   'criticisum',
#   'criticizement',
#   'cridictcisim',
#   'criticisms',
#   'critisizime',
#   'criticisem',
#   'critisizim',
#   'critisision',
#   'critizism',
#   'crisiam',
#   'critisisam',
#   'criticsm',
#   'critisiam',
#   'criticizasm',
#   'critizum',
#   'criticizin',
#   'critizisum',
#   'critizen',
#   'critizem',
#   'critzen',
#   'cretacesum',
#   'courtesisum',
#   'critisym',
#   'cretisism',
#   'critizisim',
#   'criticitisem',
#   'crypticism',
#   'critizizam',
#   'critisesimon',
#   'critisem',
#   'critcism',
#   'criticem',
#   'criciticisms',
#   'cirtissimum',
#   'critici',
#   'criticm',
#   'critism',
#   'critision',
#   'crytisym',
#   'criticizm',
#   'courtisum',
#   'critisizen',
#   'critizitim',
#   'criticum'],
#  'golden': ['goldin', 'gloden'],
#  'sines': ['sinse'],
#  'divide': ['devide', 'devide', 'divid'],
#  'subtracts': ['substracts'],
#  'there_had': ['therad'],
#  'criticise': ['critisize'],
#  'sweetest': ['sweetes'],
#  'explained': ['explan',
#   'epled',
#   'exclimed',
#   'exeplande',
#   'explainded',
#   'ecspained',
#   'explard',
#   'exslanded',
#   'explanned',
#   'expanel',
#   'exesnd',
#   'expaned',
#   'exlpand',
#   'explain',
#   'explaind',
#   'eixplaned',
#   'exsplaned',
#   'eplained',
#   'exsplain',
#   'explaid',
#   'explaned',
#   'epland',
#   'expand',
#   'extamed',
#   'explant',
#   'ekplaned',
#   'expaine',
#   'exploxen',
#   'explairded',
#   'explane',
#   'expland',
#   'expent',
#   'exclaimed',
#   'exprand',
#   'exple',
#   'exclamed'],
#  'brought': ['broght',
#   'broug',
#   'brough',
#   'brough',
#   'brot',
#   'bught',
#   'brort',
#   'brougth',
#   'bought'],
#  'remnant': ['reminent'],
#  'sizeable': ['sizable'],
#  'opponents': ['oppenerts'],
#  'spoke': ['spoak', 'spock', 'spok', 'spook'],
#  'browse': ['bbrose'],
#  'music': ['muic', 'muice'],
#  'telegraph': ['telagraph'],
#  'strike': ['stricke', 'sricke', 'strick'],
#  'until': ['intal',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'untill',
#   'uatill',
#   'untl'],
#  'holy': ['wholy', 'holly', 'holey'],
#  'relax': ['relacks'],
#  'successful': ['sucksesful',
#   'sucsselful',
#   'seckesful',
#   'sacsesful',
#   'sussecful',
#   'sucsesfult',
#   'sususful',
#   'seccesful',
#   'suxsesful',
#   'sucsful',
#   'sussfull',
#   'sucsesfull',
#   'sucssuful',
#   'sucsessful',
#   'siccesefull',
#   'sursenful',
#   'suxsusful',
#   'suksesfull',
#   'succful',
#   'successfull',
#   'successfull',
#   'sucessful',
#   'succesfull',
#   'secsecfuly',
#   'sucessfull',
#   'sucessfull',
#   'successeful',
#   'suxcessful',
#   'sesesful',
#   'scucfull',
#   'succesfel',
#   'sexcful',
#   'suckessful',
#   'succsesfull',
#   'secessful',
#   'sucfull',
#   'successfuly',
#   'seceful',
#   'suckcesfull',
#   'surseful',
#   'saseful',
#   'sucksfull',
#   'susesful',
#   'surou',
#   'sucefull',
#   'succeful',
#   'sucsfully',
#   'sexself',
#   'succesfully',
#   'uscsful',
#   'sucesful',
#   'sucesful',
#   'sucseful',
#   'succfull',
#   'succusfull',
#   'secsecful',
#   'sucksesfull',
#   'suchsefull',
#   'sacksesful',
#   'scuksefuly',
#   'succesful',
#   'succesful',
#   'sucsefully',
#   'secseful',
#   'succeshful',
#   'sucsessfull',
#   'suchesbull',
#   'sucsesfle',
#   'suxsefal',
#   'sucsesful',
#   'suceseful',
#   'sukseful',
#   'succsessful',
#   'succsefull',
#   'suskfull',
#   'suceful',
#   'sucesfull',
#   'succsesful',
#   'sucesfful',
#   'sussefull',
#   'secsesful'],
#  'hurt': ['heart', 'hert', 'hert', 'hert', 'hearte'],
#  'glass': ['glas', 'glars'],
#  'reversible': ['reversable'],
#  'tying': ['tieing'],
#  'hole': ['hol', 'hold', 'holler'],
#  'hold': ['hod', 'holed'],
#  'circumstances': ['circumstaces'],
#  'locked': ['lock', 'locked', 'lockd'],
#  'pursue': ['persue', 'persue', 'persue', 'presue'],
#  'accomplishment': ['acomplishment'],
#  'apologetics': ['apolegetics'],
#  'locker': ['loker'],
#  'example': ['exemple', 'exmaple', 'exsample', 'exmple'],
#  'household': ['houshe'],
#  'artillery': ['artillary'],
#  'organized': ['oranised', 'orginized'],
#  'caution': ['causion', 'cortion'],
#  'want': ['wont',
#   'wants',
#   'what',
#   'mant',
#   'whant',
#   'whant',
#   'whant',
#   'whant',
#   'whant',
#   'whant',
#   'whant',
#   'wand',
#   'watn',
#   "whan't",
#   "whan't",
#   'woth',
#   'wnat',
#   'whon',
#   'whont',
#   'whont',
#   'whont',
#   'whont',
#   'whont',
#   "won't",
#   "won't",
#   "won't",
#   "won't",
#   'wernt',
#   'went',
#   'wat'],
#  'preferably': ['preferrably'],
#  'hog': ['hag'],
#  'hoe': ['how', 'ho'],
#  'complaining': ['complanig'],
#  'travel': ['travle', 'travill', 'travell'],
#  'damage': ['damaged',
#   'damadge',
#   'dameage',
#   'damge',
#   'damage',
#   'dammage',
#   'damuge',
#   'damagage',
#   'damaze',
#   'danage',
#   'damnage',
#   'damgous'],
#  'machine': ['mecichly',
#   'merchen',
#   'meshien',
#   'michin',
#   'minhen',
#   'machane',
#   'merchain',
#   'mishn',
#   'maechen',
#   'mosien',
#   'moter',
#   'masir',
#   'matchine',
#   'macine',
#   'mashen',
#   'machiene',
#   'merchine',
#   'mishing',
#   'meirshin',
#   'mechine',
#   'micshine',
#   'mashin',
#   'mashine',
#   'manchine',
#   'mching',
#   'mesen',
#   'macien',
#   'muchien',
#   'mrosin',
#   'machian',
#   'masgen',
#   'mshin',
#   'machein',
#   'macheine'],
#  'how': ['hou', 'haw'],
#  'hot': ['thot', 'rat', 'hoot', 'hala', 'hote', 'aht', 'tert', 'hat'],
#  'hop': ['hope'],
#  'cheetah': ['cheter'],
#  'preferable': ['preferrable'],
#  'fanaticism': ['fanatism'],
#  'vaccination': ['vacinnation'],
#  'beauty': ['beuty', 'bueaty'],
#  'outlawed': ['oulawed'],
#  'wrong': ['wrang',
#   'wronge',
#   'ron',
#   'rong',
#   'rong',
#   'rong',
#   'long',
#   'rog',
#   'wong',
#   'ronge',
#   'ro',
#   'worng'],
#  'monolithic': ['monolite'],
#  'short-tempered': ['short_tempered'],
#  'effective': ['affective'],
#  'caisson': ['casion'],
#  'headquarters': ['headquoters'],
#  'season': ['seson'],
#  'signatories': ['signitories'],
#  'baggage': ['bagage'],
#  'orally': ['erally'],
#  'snowballs': ['snow_ball'],
#  'keeps': ['keep'],
#  'wind': ['win', 'wid'],
#  'restriction': ['restrici'],
#  'dreamed': ['dremd'],
#  'misdemeanor': ['misdemenor', 'misdameanor'],
#  'vary': ['varie'],
#  'sunshine': ['sunshin'],
#  'nazareth': ['nazereth'],
#  'fir': ['fur'],
#  'his': ["he's",
#   "he's",
#   "he's",
#   'this',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is',
#   'hes',
#   'it',
#   'its',
#   'hed',
#   'has',
#   'him',
#   'he',
#   'he',
#   'he',
#   'he'],
#  'fit': ['fite', 'fanit', 'fid'],
#  'unforeseen': ['unforseen'],
#  'heretofore': ['heretofor'],
#  'secede': ['seceed'],
#  'survivors': ['survivers'],
#  'coach-load': ['coach_load'],
#  'distinguishing': ['distingishing'],
#  'insubstantial': ['insubstancial'],
#  'hidden': ['hidon'],
#  'him': ['em',
#   'his',
#   'ham',
#   'hon',
#   'heme',
#   'im',
#   'thi',
#   'hm',
#   'hem',
#   'hime',
#   'hin',
#   'he'],
#  'grievous': ['grievious'],
#  'interrupt': ['interupt', 'interupt'],
#  'blink': ['blnk'],
#  'eisenhower': ['eisenhhower'],
#  'scholar': ['scholer'],
#  'rumour': ['rumer', 'rummer'],
#  'represents': ['repreents'],
#  'queues': ['ques'],
#  'shoelace': ['shoe_lace'],
#  'arrow': ['arow'],
#  'volcano': ['volcanoe'],
#  'dumpy': ['dunpty'],
#  'obdurate': ['obdirate'],
#  'preceded': ['preceeded'],
#  'financial': ['vaysuntte',
#   'fiynalle',
#   'finachle',
#   'finashall',
#   'finaancle',
#   'finatul',
#   'finantual',
#   'fintrol',
#   'fina',
#   'finnance',
#   'financhial',
#   'finanturel',
#   'finasle',
#   'finanshel',
#   'fineshel',
#   'financal',
#   'finnanle',
#   'finanial',
#   'financhel',
#   'firanshal',
#   'finachial',
#   'finashal',
#   'finenashsure',
#   'finatial',
#   'finane',
#   'fianation',
#   'finantial',
#   'finacwell',
#   'firnashal',
#   'fenecherue',
#   'finanshiol',
#   'financual',
#   'finachel',
#   'finasial',
#   'finacal',
#   'finatoil',
#   'finantal',
#   'finacial',
#   'finesha',
#   'fiancial',
#   'finashel',
#   'finatical',
#   'firnanshel',
#   'finanction',
#   'fineancal',
#   'finalshal',
#   'financhall'],
#  'snakes': ['snaks', 'snake'],
#  'archetypes': ['archtypes'],
#  'garment': ['garmet'],
#  'teddy_boy': ['teddoy', 'tedeboy', 'tedeboy', 'tedeboy', 'tedeboy'],
#  'spider': ['spiter'],
#  'turnip': ['turnup'],
#  'precedes': ['preceeds'],
#  'fortnight': ['fort_night'],
#  'laboratory': ['labory',
#   'labotorey',
#   'laboraty',
#   'labritory',
#   'labroratory',
#   'lavatory',
#   'labortory',
#   'labertory',
#   'labrotory',
#   'laboatory',
#   'libertory',
#   'labatory',
#   'laboretory',
#   'labratory',
#   'labratory',
#   'laberotary',
#   'labitory',
#   'labaratory',
#   'labetory',
#   'lavoratory',
#   'elatory',
#   'lab',
#   'laveratory',
#   'labartory',
#   'labortary',
#   'laboritory',
#   'labority',
#   'laborotory',
#   'labarotory',
#   'lavortory',
#   'laborbtory',
#   'laberatory',
#   'lavratory'],
#  'ring': ['rings'],
#  'whip': ['wip'],
#  'excepting': ['exepting'],
#  'encourage': ['incourage', 'encorage', 'encourge', 'encourg'],
#  'engineer': ['engeneer', 'engieneer', 'enginer'],
#  'foundation': ['foundition', 'fondation'],
#  'inhabitants': ['habitants'],
#  'assured': ['asured'],
#  'threatened': ['thretened'],
#  'surveys': ['survays', 'servays'],
#  'grapes': ['graps'],
#  'sheet': ['sheat', 'sheat', 'shet'],
#  'estimate': ['estamate'],
#  'knit': ['knitt', 'niet', 'nit'],
#  'universally': ['universaly'],
#  'enormous': ['enormas', 'emerous', 'enourmous', 'enormus'],
#  'ate': ['et', 'aet', 'eat', 'eat', 'eat', 'ete'],
#  'scruff': ['scruf'],
#  'reprimanded': ['repremanded'],
#  'dinner-hour': ['dinner_hour'],
#  "today's": ['todays'],
#  'sallies': ['sally'],
#  'wash': ['wach', 'wosh'],
#  'instruct': ['instruck'],
#  'customization': ['custamisation'],
#  'bitten': ['biten'],
#  'rhododendron': ['rhododrendon'],
#  'basketball': ['baskball',
#   'basketball',
#   'basketbale',
#   'basket-ball',
#   'baskt-ball',
#   'baskeball',
#   'basket-ball',
#   'bascketball',
#   'basket-ball',
#   'baskitball',
#   'bascket-ball',
#   'basket_ball',
#   'bastestball'],
#  'service': ['cirvice', 'survice', 'servise', 'servace'],
#  'similarly': ['similarily', 'similarily'],
#  'engagement': ['enagement'],
#  'needed': ['need', 'nedded', 'mided', 'neaded'],
#  'perturbations': ['pertubations'],
#  'master': ['mater'],
#  'architect': ['archetect'],
#  'listen': ['lisen', 'lesson', 'lisn', 'leasten', 'listern', 'listern'],
#  'geneva': ['geniva'],
#  'snooty': ['snoty'],
#  'predictable': ['predicable'],
#  'crawl': ['crol', 'crall'],
#  'positively': ['positivly'],
#  'sidereal': ['sedereal', 'sideral'],
#  'showed': ['showd', 'shod'],
#  'approximations': ['appoximations'],
#  'tree': ['treee', 'tre', 'three', 'tee'],
#  'omnivorous': ['omniverous'],
#  'project': ['progetr',
#   'proget',
#   'prget',
#   'pojert',
#   'projer',
#   'prung',
#   'commet',
#   'pgett',
#   'projet',
#   'projoc',
#   'progect',
#   'porait',
#   'poujent',
#   'projent',
#   'projexty',
#   'poragced',
#   'porcet'],
#  'pneumonia': ['nuemonia',
#   'memonia',
#   'pnenonia',
#   'pnuemonia',
#   'phneumonia',
#   'ammonia',
#   'pnmonia',
#   'phemonia',
#   'pneumaine',
#   'phneomia',
#   'phenomia',
#   'pnemounia',
#   'nomina',
#   'phenominia',
#   'phneomina',
#   'pnenumoia',
#   'phewmonia',
#   'pneimonia',
#   'newmonia',
#   'amnonnia',
#   'phemonuia',
#   'pneunomia',
#   'amomea',
#   'phenioma',
#   'nephonia',
#   'pheunomia',
#   'phenomenia',
#   'phunmonia',
#   'phnomeia',
#   'peneumia',
#   'phomonia',
#   'phumonia',
#   'pnumonia',
#   'pheuphmonia',
#   'pnemoninia',
#   'pneunonia',
#   'phonimonu',
#   'phuemonia',
#   'ponuime',
#   'anumonian',
#   'anomina',
#   'phnomia',
#   'pneaumonia',
#   'phenoumonia',
#   'phnumonia',
#   'pnomonia',
#   'phenoumina',
#   'penmonia',
#   'phenoumia',
#   'newmony',
#   'phenumia',
#   'pnueounia',
#   'phenimonia',
#   'numonia',
#   'penominia',
#   'phnumonia',
#   'pounia',
#   'puemonia',
#   'pnemonia',
#   'pnenomionia',
#   'phenomu',
#   'pneumia',
#   'pneumnia',
#   'pheomena',
#   'pnenonea',
#   'phemomina',
#   'phenomnia',
#   'anonianu',
#   'phmoinia',
#   'pneurminu',
#   'phnemona',
#   'pheunomina',
#   'pheumonia',
#   'phemonuime',
#   'pneumonia',
#   'phnenimonia',
#   'pheumonia',
#   'phnuemonia',
#   'namoia',
#   'nephenoma',
#   'namouny',
#   'pheneumonia',
#   'pnumonenia',
#   'numonuia',
#   'pneumunia',
#   'nemonia',
#   'pnumonea',
#   'phunemonia',
#   'peunmonia',
#   'pneumphia',
#   'neumonia',
#   'pnenomia',
#   'knemonu',
#   'phnemonia',
#   'phnemounia',
#   'pnumeia',
#   'pneomonia',
#   'peunomia',
#   'phomoniow',
#   'phonia',
#   'demondia',
#   'phmeuaina',
#   'phenemonia',
#   'numoia',
#   'remote',
#   'penumonia',
#   'munonia',
#   'phenumonia',
#   'pneuammia',
#   'amonia'],
#  'idle': ['idel', 'ide'],
#  'readjusted': ['reajusted'],
#  'seminary': ['seminery'],
#  'feeling': ['feling', 'felling', 'fealing'],
#  'acquisition': ['aquisistion', 'aquisition'],
#  'a_lot': ['lot', 'alote', 'alot', 'alot'],
#  "to-day's": ['two_days',
#   'todays',
#   "todays'",
#   'to-days',
#   "today's",
#   'todaies',
#   'to_days'],
#  'runner': ['runer'],
#  'dozen': ['doxen', 'dosen'],
#  'wholesome': ['wholsome', 'holesome'],
#  'courier': ['coururier'],
#  'responsible': ['resmoserbl',
#   'responsable',
#   'responcible',
#   'reponsible',
#   'reposable'],
#  'metallic': ['metalic'],
#  'asymmetric': ['assymmetric', 'asymetric', 'assymetric'],
#  'bang': ['bankg', 'bankg', 'bankg', 'bankg'],
#  'causing': ['corsing', 'coursing'],
#  'absorbed': ['asorbed', 'abo'],
#  'amusing': ['amsing'],
#  'doors': ['doers', 'dors'],
#  'responsibly': ['responsably'],
#  'jones': ['johnes'],
#  'committing': ['commiting', 'commiting', 'comiting', 'comitting'],
#  'shall': ['shale', 'sall', 'she', 'shal'],
#  'object': ['objet'],
#  'a_little': ['alitl', 'alittle'],
#  'mouth': ['moth'],
#  'letter': ['letre', 'teller', 'leter'],
#  'conceded': ['conseived'],
#  'professor': ['professer',
#   'profesor',
#   'proffessor',
#   'proffesor',
#   'proffesor'],
#  'camp': ['kamp', 'canp'],
#  'consummate': ['consumate'],
#  'nineteenth': ['ninteenth'],
#  'scream': ['scem', 'screem', 'screm'],
#  'incomplete': ['incompleet', 'incomplot'],
#  'marvel': ['marval'],
#  'polypropylene': ['polypropalene'],
#  'bomb': ['baumb',
#   'bombe',
#   'bome',
#   'bomm',
#   'bown',
#   'bonod',
#   'book',
#   'bom',
#   'bambe',
#   'boom'],
#  'insects': ['insexs'],
#  'gauge': ['gadg',
#   'gape',
#   'garge',
#   'gare',
#   'gange',
#   'gang',
#   'tade',
#   'garer',
#   'gage',
#   'gach',
#   'gagde',
#   'cauge',
#   'gams',
#   'gadje',
#   'bergage',
#   'gradnang',
#   'gar',
#   'grage',
#   'gagech',
#   'garind',
#   'gag',
#   'gaog',
#   'cage',
#   'gargch',
#   'gadeg',
#   'rage',
#   'gaige',
#   'gade',
#   'gager',
#   'guage',
#   'gadge',
#   'ghase',
#   'guadge',
#   'gaoge',
#   'gaged',
#   'geich'],
#  'lessons': ["lesson's",
#   'lessens',
#   'lesons',
#   'leasons',
#   'lessions',
#   'listerse',
#   'lesson'],
#  'busy': ['bise', 'buisy', 'bussy', 'bisy'],
#  'shuffling': ['shufarling'],
#  'than': ['then', 'thna', 'tahn', 'that'],
#  'bush': ['buch', 'buch'],
#  'touched': ['tesded',
#   'toure',
#   'cher',
#   'toched',
#   'theed',
#   'tost',
#   'tuched',
#   'tusted',
#   'toughed',
#   'tosh',
#   'touch',
#   'toached',
#   'tache',
#   'tucked',
#   'tust',
#   'tutet',
#   'toght',
#   'tuses',
#   'tush',
#   'tougched',
#   'tacah',
#   'tuchd',
#   'toch',
#   'toulched',
#   'turst',
#   'toutched',
#   'chuched',
#   'trosh',
#   'tiups',
#   'stuched',
#   'tuch',
#   'thach',
#   'touh',
#   'thucht',
#   'tashed'],
#  'rich': ['rick'],
#  'rice': ['rise'],
#  'lady': ['lade', 'ladey', 'ladiy', 'ladys'],
#  'plate': ['blate', 'plat'],
#  'stammered': ['stamerd'],
#  'terrors': ['terrours'],
#  'foremost': ['formost'],
#  'pocket': ['poket'],
#  'foundries': ['foundaries'],
#  'cushion': ['cusion'],
#  'altogether': ['alltogether', 'atlogeher', 'all_together'],
#  'jaguar': ['jagaur'],
#  'nicely': ['nicerly', 'nicly', 'micely'],
#  'boarder': ['border'],
#  'patch': ['pacth'],
#  'blew': ['blow', 'blow', 'blow', 'blue'],
#  'disaster': ['diaster'],
#  'fair': ['fare'],
#  'peripheral': ['periferal'],
#  'radius': ['radiuss', 'radious'],
#  'fail': ['fale'],
#  'nocturnal': ['nocternal'],
#  'hammer': ['hamer'],
#  'best': ['bets',
#   'be',
#   'bast',
#   'dest',
#   'bass',
#   'beets',
#   'beat',
#   'bist',
#   'biwes',
#   'besh',
#   'besd',
#   'mest',
#   'beast',
#   'bettes',
#   'bister',
#   'bess',
#   'bes',
#   'bet'],
#  'lots': ['losts', 'lotes', 'lot', 'lost'],
#  'propagates': ['propogates'],
#  'score': ['skore', 'scor'],
#  'side': ['sied', 'se', 'sid'],
#  'preserve': ['preseve'],
#  'claws': ['clors'],
#  'never': ['neve',
#   'neve',
#   'newer',
#   'mever',
#   'nere',
#   'nof',
#   'knver',
#   'neaver',
#   'nether',
#   'nether',
#   'nef',
#   'neiver',
#   'nerth',
#   'naver',
#   'nven',
#   'nese',
#   'ner',
#   'neven',
#   'nver'],
#  'extend': ['exstend', 'extand'],
#  'nature': ['nacher', 'nuture', 'natior', 'm'],
#  'rolled': ['rolld', 'rold'],
#  'invigorated': ['envigorated'],
#  'souvenir': ['souvenier', 'suvenere', 'souviner'],
#  'extent': ['exstent'],
#  'wheelbarrow': ['wheel_barrow'],
#  'debt': ['dept', 'deat'],
#  'tyranny': ['tyrrany', 'tyrrany', 'tyrany'],
#  'patented': ['pattented'],
#  'accident': ['and',
#   'aserdent',
#   'exded',
#   'asden',
#   'sedent',
#   'acadent',
#   'ataren',
#   'axcident',
#   'askendent',
#   'castan',
#   'asdent',
#   'anitharent',
#   'esadend',
#   'a_canet',
#   'acedcedt',
#   'asde',
#   'anteght',
#   'aciddent',
#   'accicent',
#   'andandn',
#   'acciendent',
#   'aciedent',
#   'askedent',
#   'agisted',
#   'axedet',
#   'ascended',
#   'accierdent',
#   'asident',
#   'acsident',
#   'asedend',
#   'exedelt',
#   'harcent',
#   'accsident',
#   'andexns',
#   'acsdent',
#   'accend',
#   'axseadent',
#   'andet',
#   'accxident',
#   'aciadent',
#   'exiedent',
#   'axs',
#   'axerdent',
#   'advainet',
#   'exedent',
#   'andires',
#   'acsedent',
#   'andient',
#   'asadun',
#   'akcdent',
#   'acedent',
#   'axed',
#   'andint',
#   'ancident',
#   'aken',
#   'ased',
#   'asabed',
#   'acident',
#   'afanat',
#   'xedet',
#   'axedent',
#   'acist',
#   'acdent',
#   'acs',
#   'axidint',
#   'acats',
#   'asterdet',
#   'accdient',
#   'axedents',
#   'acddent',
#   'axident',
#   'addinent',
#   'acdend',
#   'accedent'],
#  'chirped': ['cherped'],
#  'country': ['ocuntry',
#   'carty',
#   'cout',
#   'contry',
#   'county',
#   'coontry',
#   'countrie'],
#  'incense': ['insense'],
#  'levitating': ['levetating'],
#  'planned': ['planed', 'planed'],
#  'asked': ['ask', 'ask', 'ask', 'ask', 'ask', 'askt', 'arsed', 'arsed'],
#  'unsymmetrical': ['unsyme'],
#  'vain': ['vane'],
#  'humming': ['huming'],
#  'cardboard': ['cardbord'],
#  'source': ['sorce', 'aource', 'sauce', 'sourse'],
#  'union': ['unioun'],
#  'criticised': ['critisized'],
#  'much': ['must', 'mush', 'mush', 'mush', 'mush', 'mush', 'march', 'mach'],
#  'stadium': ['staydium'],
#  'privilege': ['priviledge',
#   'priviledge',
#   'priviledge',
#   'privlage',
#   'privelege',
#   'privelege',
#   'privelige',
#   'privelige',
#   'privaledge',
#   'pervieledges',
#   'prilavage',
#   'privoledge',
#   'prevelige',
#   'privilages',
#   'privielage',
#   'priviliage',
#   'previlege',
#   'prlige',
#   'privaledged',
#   'prilavge',
#   'providge',
#   'privelage',
#   'privelidge',
#   'privileged',
#   'priviladge',
#   'previllage',
#   'privieloge',
#   'priveelege',
#   'privilage',
#   'privilage',
#   'preminage',
#   'previlage',
#   'previlidge',
#   'privalogy',
#   'privalidge',
#   'priviage',
#   'privilidged',
#   'purlgy',
#   'privledge',
#   'prividleged',
#   'privileelge',
#   'privalage',
#   'prilviage',
#   'prevelage',
#   'privialage',
#   'privilidge',
#   'privilige',
#   'prilvege',
#   'priveleage',
#   'privi'],
#  'fry': ['fri', 'frie'],
#  'incompetent': ['incompetant'],
#  'life': ['lif', 'lief', 'live', 'lefe'],
#  'spit': ['spite'],
#  'eastern': ['eastren'],
#  'wish': ['wich', 'wis', 'whish'],
#  'lift': ['left'],
#  'toboggan': ['talogon',
#   'tabogan',
#   'tabogen',
#   'tobbogan',
#   'tabogoon',
#   'tobagon',
#   'tobagan',
#   'tobogon',
#   'tobugon',
#   'tobogan',
#   'tobon',
#   'taboggan',
#   'tobogar',
#   'tobbogen',
#   'tobogurn',
#   'tobogn',
#   'taboog',
#   'tobaggan',
#   'tobboan',
#   'tabbogan',
#   'torbogen',
#   'conboggon',
#   'tobag',
#   'toboggen',
#   'toban',
#   'tobgen',
#   'tobogen',
#   'tabbogon',
#   'tobogane',
#   'tobacon',
#   'talbogan',
#   'tobogone',
#   'terbogen'],
#  'child': ['cild'],
#  'worked': ['work', 'workt', 'worted'],
#  'spin': ['spen'],
#  'skilfully': ['silfely',
#   'scilfle',
#   'strillfully',
#   'sceiful',
#   'fouale',
#   'lefle',
#   'sifle',
#   'scilfl',
#   'scillfully',
#   'skillfuly',
#   'skillverly',
#   'slhing',
#   'scearfolly',
#   'scferly',
#   'skillfel',
#   'squialy',
#   'sillaf',
#   'scilfly',
#   'sckeleft',
#   'skyillferley',
#   'saill',
#   'scify',
#   'skilfuly',
#   'silf-fele',
#   'skilfuley',
#   'silfle',
#   'clefler',
#   'silag',
#   'scillfuly',
#   'careing',
#   'skiverly',
#   'sifrle',
#   'sivle',
#   'skillforlly',
#   'skellfortly',
#   'sdillfully',
#   'skefferly',
#   'skill-fullie',
#   'skifly',
#   'skcinfulle',
#   'scifuly',
#   'skillferly',
#   'sarefully',
#   'soft',
#   'skifaly',
#   'sciferly',
#   'skilfarly',
#   'sqilferly',
#   'skinfuly',
#   'scill_filly',
#   'skelfuly',
#   'skifle',
#   'scillferle',
#   'scilfully',
#   'skillfully',
#   'scifule',
#   'cifarte',
#   'scillfley',
#   'skiffuly',
#   'scilferly',
#   'skilly',
#   'skeaferly',
#   'sall',
#   'skilfoly',
#   'sech',
#   'sillfully',
#   'skillful',
#   'shfally',
#   'skifully',
#   'scifeley',
#   'skilferly',
#   'selfer',
#   'sciverly',
#   'slikely',
#   'sclfoly',
#   'scilfuly'],
#  'commerce': ['comerce'],
#  'adaptations': ['adaptions'],
#  'dissect': ['disect'],
#  'employ': ['employe', 'imploy'],
#  'visit': ['visite', 'viste', 'vist'],
#  'played': ['paly', 'play', 'plays', 'bagt'],
#  'player': ['playa'],
#  'anticipating': ['antisepating',
#   'antisapiting',
#   'anticipitating',
#   'taniseapating',
#   'antispating',
#   'anticicitating',
#   'antizapating',
#   'antiscimation',
#   'antecipating',
#   'anticapate',
#   'anticipation',
#   'ancisapating',
#   'antiecpating',
#   'antisapit',
#   'anticepating',
#   'anticopening',
#   'anntisipation',
#   'antiapating',
#   'antcspating',
#   'anticpating',
#   'anticipting',
#   'anticiputed',
#   'antistipating',
#   'anntisapating',
#   'antisipainting',
#   'antiscipating',
#   'antisispating',
#   'atticpate',
#   'antisipating',
#   'antisepate',
#   'anticapting',
#   'anticipate',
#   'antasipation',
#   'anticapating',
#   'anticipateing',
#   'antisupate',
#   'antisapating',
#   'anticap'],
#  'foot-and-mouth': ['footandmouth', 'footanmouth'],
#  'violin': ['voilion', 'volin', 'vioiln'],
#  'oxymoron': ['oximoron'],
#  'damaged': ['dagmed',
#   'damatge',
#   'dames',
#   'damiged',
#   'damge',
#   'dameaged',
#   'damidge',
#   'damidgd',
#   'damed',
#   'damanged',
#   'damised',
#   'daned',
#   'damgedid',
#   'damadge',
#   'dadge',
#   'damedged',
#   'damagd',
#   'damage',
#   'domg',
#   'daeged',
#   'depbiced',
#   'damigaigd',
#   'dammaged',
#   'daniged',
#   'demges',
#   'damged',
#   'dam',
#   'damagtd',
#   'damdend',
#   'damadged',
#   'bamaged',
#   'dmeg',
#   'dameged',
#   'ecage',
#   'danaged',
#   'dammage',
#   'damges',
#   'danmaged',
#   'damige',
#   'damigid',
#   'damedge'],
#  'things': ['thigns',
#   'tings',
#   'thinks',
#   'thing',
#   'fens',
#   'thigsn',
#   'thnigs',
#   'think',
#   'think',
#   'thigs'],
#  'demands': ['diemands'],
#  'split': ['splite', 'spilt'],
#  'babies': ['babys'],
#  'fairly': ['faily', 'farly', 'fairlu'],
#  'married': ['marride',
#   'madrri',
#   'marryied',
#   'marryid',
#   'marreid',
#   'marrede',
#   'marriad',
#   'maried',
#   'marid',
#   'marred',
#   'marrid'],
#  'typhoid': ['tifoid', 'tyfoid'],
#  'middle-aged': ['middle_age'],
#  'supper': ['super'],
#  "someone's": ['some_ones'],
#  'peremptory': ['preemptory'],
#  'rescinded': ['resinded'],
#  'academic': ['accademic', 'acedemic'],
#  'subpoena': ['subpena', 'sepina'],
#  'form-mistress': ['formmistress', 'formistress', 'formmisstress'],
#  'corporate': ['corparate', 'corparate'],
#  'plaque': ['placque'],
#  'capitol': ['capital'],
#  'distribute': ['distribut', 'distrubute'],
#  'sleepy': ['sleppy', 'sleepey'],
#  'financially': ['fianancally',
#   'financial',
#   'financilly',
#   'funiluty',
#   'finatially',
#   'financely',
#   'fincially',
#   'finnancially',
#   'financialy',
#   'financialy',
#   'finically',
#   'fininculay',
#   'fineanancely',
#   'famficay',
#   'finatually',
#   'finattioncely',
#   'finachily',
#   'finincially',
#   'finnancilly',
#   'finantially',
#   'financally',
#   'fenancialy',
#   'fimashly',
#   'finnacally',
#   'financhally',
#   'finiancle',
#   'finally',
#   'finiancially',
#   'finaciancally',
#   'finacially',
#   'financuly',
#   'fnaniancly',
#   'financeally',
#   'finnacily',
#   'finincally',
#   'financle',
#   'financel',
#   'finiancely',
#   'financly',
#   'finaitially',
#   'fananually',
#   'fianancially',
#   'financhilly',
#   'finantionally',
#   'finately',
#   'finiancally',
#   'finantually',
#   'finiancialy',
#   'finationly',
#   'finanialy',
#   'fanincally',
#   'financily',
#   'fiancially',
#   'fianicially',
#   'finitually',
#   'finaling',
#   'finacilly',
#   'fianiclly',
#   'finaily',
#   'finncually',
#   'fanacialy',
#   'financinally',
#   'financually',
#   'finnanially',
#   'finanically',
#   'finicially',
#   'finially'],
#  'portrayed': ['protrayed'],
#  'succeeding': ['suceeding'],
#  'previous': ['previvous', 'preveous', 'previos', 'previus'],
#  'purchased': ['perchased'],
#  'sciences': ['se'],
#  'old-fashioned': ['old_fashion', 'old_fashend', 'oldfashioned'],
#  'had': ['hut',
#   'head',
#   'ad',
#   'han',
#   'hab',
#   'hade',
#   'hade',
#   'hed',
#   'add',
#   'ade',
#   'at',
#   'have',
#   'have',
#   'av',
#   'has',
#   'has',
#   'hat',
#   'haed',
#   'aud'],
#  'thickening': ['thikning'],
#  'connecticut': ['conneticut'],
#  'obedient': ['obediant', 'obediant', 'obedent'],
#  'innocent': ['inoscent',
#   'incensent',
#   'innoncent',
#   'innocense',
#   'inocence',
#   'insient',
#   'inosent',
#   'incouncent',
#   'inocient',
#   'inasence',
#   'innocent',
#   'ininsit',
#   'inocience',
#   'inocent',
#   'innosent',
#   'innisit',
#   'inasent',
#   'inconnent',
#   'innocents',
#   'innonce',
#   'imisant',
#   'innocence',
#   'innacent',
#   'innicent',
#   'enocent',
#   'ennocent',
#   'innocnce',
#   'innoscent',
#   'iniscent',
#   'inoncent',
#   'inoccent',
#   'insent',
#   'innoint',
#   'innorcent',
#   'inocense',
#   'inocent'],
#  'prison': ['prisern'],
#  'has': ['hase', 'hase', 'as', 'as', 'as', 'as', 'his', 'hos', 'have'],
#  'hat': ['hot'],
#  'every_time': ['everytime'],
#  'good-humoured': ['good_humer'],
#  'confidentially': ['confidentally'],
#  'disagreement': ['dissagreement'],
#  'possible': ['possibly',
#   'pissible',
#   'possable',
#   'possable',
#   'possable',
#   'posible'],
#  'unequivocally': ['unequivocaly'],
#  'possibly': ['possably', 'possiply', 'possible'],
#  'birth': ['berth'],
#  'missouri': ['misouri'],
#  'shadow': ['shaddow', 'shodow'],
#  'unique': ['uneque'],
#  'occurring': ['occuring', 'occuring'],
#  'desire': ['disire'],
#  'psychological': ['psycological'],
#  'remind': ['remined',
#   'remained',
#   'reminded',
#   'remond',
#   'remied',
#   'rembenes',
#   'remine',
#   're_mind',
#   'remimed',
#   'renind',
#   'remaind'],
#  'pavement': ['pathment', 'pavment'],
#  'steps': ['staps'],
#  'malnutrition': ['manutriction'],
#  'prologue': ['prolague',
#   'parlog',
#   'prologd',
#   'plolog',
#   'prolode',
#   'proloug',
#   'prolad',
#   'proloame',
#   'prolong',
#   'prlog',
#   'prologe',
#   'prolougle',
#   'browlog',
#   'prealog',
#   'prolarge',
#   'prolouge',
#   'prollog',
#   'prlock',
#   'porlong',
#   'prolog'],
#  'ithaca': ['ihaca'],
#  'misdemeanors': ['misdameanors', 'misdemenors'],
#  'swedish': ['sweedish'],
#  'attorney': ['arteny',
#   'erternly',
#   'erterey',
#   'entereny',
#   'entany',
#   'atury',
#   'ertany',
#   'arterny',
#   'aterna',
#   'ertiney',
#   'aterny',
#   'eneretel',
#   'aterney',
#   'erterny',
#   'entely',
#   'aterning',
#   'aturney',
#   'atterney',
#   'atorney',
#   'erterney',
#   'eterny',
#   'enterny',
#   'attaney',
#   'interne',
#   'atterny',
#   'ertenely',
#   'aturny',
#   'eterany',
#   'atternary',
#   'aturne',
#   'atturney'],
#  'right': ['write', 'rite', 'rigth', 'rigth', 'rigth'],
#  'old': ['ald', 'ol', 'lod', 'lod', 'lod', 'lod', 'olf'],
#  'creek': ['creak'],
#  'crowd': ['croud', 'croud'],
#  'people': ['pople',
#   'pople',
#   'peaper',
#   'peepull',
#   'pleople',
#   'porle',
#   'pepo',
#   'pipoll',
#   'peiple',
#   'poeple',
#   'peapl',
#   'peps',
#   'po',
#   'peple',
#   'pecial',
#   'peopl',
#   'pepall',
#   'peropel',
#   'peopel',
#   'peopel',
#   'peopal',
#   'pelele',
#   'pepal',
#   'peolpe',
#   'peropl',
#   'peaple',
#   'peol',
#   'pepole'],
#  'crown': ['croun'],
#  'insistence': ['insistance', 'insistance'],
#  'harassment': ['harasment', 'harrasment'],
#  'creep': ['creap'],
#  'enemies': ['emmines',
#   'enemeys',
#   'enemeies',
#   'emimies',
#   'enmenies',
#   'enameyes',
#   'enmoneys',
#   'eminies',
#   'enemes',
#   'enimes',
#   'emmies',
#   'emeny',
#   'eniemies',
#   'enimeys',
#   'enamys',
#   'enamies',
#   'enemyies',
#   'emenies',
#   'enimies',
#   'enimeies',
#   'enmies',
#   'enimeus',
#   'enemys',
#   'enemy',
#   'enanis',
#   'enimesies',
#   'ememy',
#   'emenys',
#   'enmeys',
#   'enames',
#   "enemy's"],
#  "daddy's": ['dadies'],
#  'for': ['fror',
#   'fur',
#   'fre',
#   'from',
#   'far',
#   'of',
#   'of',
#   'of',
#   'fro',
#   'fro',
#   'fore',
#   'fore',
#   'fore',
#   'fore',
#   'four',
#   'four',
#   'four',
#   'foir',
#   'in',
#   'forr',
#   'fon',
#   'foow',
#   'frou',
#   'or',
#   'fo',
#   'fo'],
#  'bottom': ['botem', 'bottem', 'botome', 'botton', 'botton', 'botom'],
#  'fox': ['foxx'],
#  'polluted': ['poluted'],
#  'continue': ['contunie'],
#  'periphery': ['perifery'],
#  'syphilis': ['syphyllis'],
#  'pollutes': ['polutes'],
#  'pinched': ['picth'],
#  'dinner-hours': ['dinner_hours'],
#  'losing': ['loosing', 'loosing', 'loseing', 'lossing', 'lossing'],
#  'memorable': ['memerable', 'memeroal'],
#  'manufacturing': ['manufactoring', 'manufaturing'],
#  'dollars': ['dollers'],
#  'anomalous': ['anomolous', 'anomalus'],
#  'recollect': ['reccollect', 'recolect'],
#  'despair': ['dispair', 'dispair', 'dispair'],
#  'slightly': ['slighlty'],
#  'raised': ['rased'],
#  'feb': ['fab'],
#  'motorbike': ['moter_bike', 'moter_bike', 'motor_bike'],
#  'facility': ['facilitie'],
#  'honeymoon': ['honey_moon', 'honymoon', 'hunemoon'],
#  'well-suited': ['well_suited'],
#  'son': ['sun'],
#  'respectable': ['respectible'],
#  'consummated': ['consumated'],
#  'sow': ['sew'],
#  'wrap': ['rap'],
#  'unambiguous': ['unabiguous'],
#  'hallo': ['alloe', 'halloe'],
#  'altitude': ['ettalared',
#   'altutadue',
#   'atitude',
#   'actitude',
#   'altetede',
#   'intertourd',
#   'altechud',
#   'altitube',
#   'altituded',
#   'elit',
#   'outertod',
#   'alteytod',
#   'altechod',
#   'asitude',
#   'autityed',
#   'attetude',
#   'elitead',
#   'alletude',
#   'outatude',
#   'eltitude',
#   'altitud',
#   'altitub',
#   'alltitude',
#   'altechoued',
#   'outitude',
#   'outertude',
#   'atlesould',
#   'altiude',
#   'alterchood',
#   'altertude',
#   'altidud',
#   'outtide',
#   'autee',
#   'altilude',
#   'autachoot',
#   'altiertetude',
#   'atalrod',
#   'altihoched',
#   'altetud',
#   'alteturen',
#   'autridude',
#   'aoteod',
#   'alterrude',
#   'outituge',
#   'oiled',
#   'altuled',
#   'aletute',
#   'atain',
#   'atasher',
#   'outderer',
#   'elingtcewed',
#   'aboule',
#   'otchod',
#   'altude',
#   'alatetude',
#   'attitood',
#   'ata',
#   'altitued',
#   'outechut',
#   'altitob',
#   'altuide',
#   'altetude',
#   'atichood',
#   'altiuded'],
#  'constantly': ['constanly', 'constently'],
#  'tame': ['tam'],
#  'width': ['with'],
#  "boy's": ['boy', 'boy', 'boy', 'boys', 'boys'],
#  'overhead': ['overhaed'],
#  'happy': ['happiy',
#   'happe',
#   'happer',
#   'appey',
#   'hapr',
#   'hope',
#   'hapy',
#   'happler',
#   'happle',
#   'happi',
#   'hape',
#   'hoppe',
#   'happert',
#   'hepe',
#   'apay',
#   'h_pping',
#   'hap',
#   'happie',
#   'glad',
#   'ape'],
#  'offer': ['ofer'],
#  'fascination': ['fasantion'],
#  'cassowary': ['cassawory', 'cassowarry'],
#  'talents': ['tallents'],
#  'understandable': ['understadable'],
#  'beech': ['beach'],
#  'safeguard': ['safegaurd'],
#  'congratulations': ['congratalation',
#   'congragalations',
#   'congrulations',
#   'congratulation',
#   'concradulations',
#   'congraulations',
#   'congradulation',
#   'congreation',
#   'comcerracarlants',
#   'congratulate',
#   'congratalutions',
#   'congrutulations',
#   'congralulations',
#   'congraulation',
#   'congratulatons',
#   'congralutations',
#   'congradulations',
#   'congradulations',
#   'congretulations',
#   'congraduation',
#   'congrationlation',
#   'conguralitions',
#   'congragulations',
#   'congratilations',
#   'congratualations',
#   'congraudulations',
#   'congratalations',
#   'congradualtions',
#   'congreatulations',
#   'congralutaions',
#   'congratilation',
#   'conglutation',
#   'congratrilations',
#   'congractulations',
#   'congraduations',
#   'congratuations',
#   'congratulions',
#   'congraturalations',
#   'congralation',
#   'congradutation',
#   'concrogulation'],
#  'genealogy': ['geneology'],
#  "else's": ['elss', 'elesers'],
#  'inside': ['insid', 'in_sis', 'in_side', 'in_side'],
#  'equalization': ['equilisation'],
#  'devices': ['def'],
#  'unanimous': ['unamenous',
#   'youmanles',
#   'umamous',
#   'anonymous',
#   'unammious',
#   'unnamious',
#   'unamamous',
#   'unanumous',
#   'umanaress',
#   'eunaminus',
#   'uniamimus',
#   'unnanomous',
#   'ununumus',
#   'unanious',
#   'unninote',
#   'unonomious',
#   'unaminus',
#   'unaninous',
#   'unenamous',
#   'unoniums',
#   'unamusts',
#   'unaniae',
#   'younamenous',
#   'uniomus',
#   'unanumas',
#   'sallanous',
#   'unamuse',
#   'unanimoses',
#   'unnanimous',
#   'unmnus',
#   'younamess',
#   'unamimus',
#   'unammius',
#   'amius',
#   'unaimous',
#   'unumanious',
#   'unacious',
#   'unananois',
#   'unnambus',
#   'unanmous',
#   'unanomous',
#   'unanus',
#   'umamilus',
#   'unanamious',
#   'unaiminous',
#   'unaminuous',
#   'unaninus',
#   'inamimus',
#   'eunamous',
#   'unanonus',
#   'unamous',
#   'unamious',
#   'unnamous',
#   'umionus',
#   'unananus',
#   'annymus',
#   'unnames',
#   'unannanus',
#   'unanamous',
#   'unanously',
#   'unanimuss',
#   'unanimos',
#   'unamus',
#   'unnadimus',
#   'unanabus',
#   'unamatous',
#   'unamaious',
#   'unannimous',
#   'unamanus',
#   'unamnious',
#   'unamonus',
#   'unanimus',
#   'eumamious',
#   'ununmious',
#   'uninamous',
#   'unatimas',
#   'unamious',
#   'uniom',
#   'unannamous',
#   'unaimulas',
#   'unimas',
#   'unnamos',
#   'unariowas',
#   'munaniuous',
#   'uniamones',
#   'unanouis',
#   'unaminonus',
#   'unnanamous',
#   'umanmuse',
#   'unamanious',
#   'unanamus',
#   'unamamouse',
#   'unanemous',
#   'unanamuse',
#   'unionous',
#   'unamanius',
#   'enaumous',
#   'unimous',
#   'unanasmons',
#   'unminus',
#   'uniminus',
#   'unitomious',
#   'unananucs',
#   'unamos',
#   'unomanious',
#   'unamies',
#   'unnous',
#   'uniamoes',
#   'unamanous',
#   'unamomus',
#   'unsannamous',
#   'unnanumus',
#   'unamaless',
#   'unaminous',
#   'unomise',
#   'unanimise',
#   'unomust',
#   'unanis'],
#  'smashed': ['spached'],
#  'palm': ['parm'],
#  'passenger': ['passanger'],
#  'juvenile': ['juvinille'],
#  'later': ['latey', 'latter', 'latter', 'lated', 'letter'],
#  'disgrace': ['discrase'],
#  'steady': ['stedy'],
#  'tournament': ['turmonent',
#   'turment',
#   'turnoments',
#   'touranment',
#   'tournment',
#   'tournanent',
#   'tournement',
#   'turament',
#   'tornamently',
#   'terminent',
#   'termament',
#   'turnement',
#   'touremount',
#   'turement',
#   'turnament',
#   'turnment',
#   'turminate',
#   'tornement',
#   'tourimant',
#   'turminent',
#   'tourament',
#   'tormenment',
#   'turmanent',
#   'tuarninent',
#   'torniment',
#   'tounement',
#   'atournament',
#   'turnmant',
#   'ternement',
#   'tormentement',
#   'tourment',
#   'turniment',
#   'tourmment',
#   'hermit',
#   'tourneyment',
#   'tourmament',
#   'tournmeant',
#   'trounment',
#   'ternament',
#   'tournnament',
#   'ternimate',
#   'tunement',
#   'teramant',
#   'terniment',
#   'termenont',
#   'turnimant',
#   'tourmad',
#   'termanent',
#   'tournamant',
#   'tournate',
#   'tornment',
#   'tornament',
#   'tourniment',
#   'turimant',
#   'tourement',
#   'torrment',
#   'turnent',
#   'touriment',
#   'termenent',
#   'tournmant'],
#  'proves': ['prooves'],
#  'exist': ['exsist'],
#  'dealer': ['dealor'],
#  'negotiations': ['nogotiations',
#   'degotitions',
#   'nogiations',
#   'negoccation',
#   'naggosiations',
#   'negossiations',
#   'negctiation',
#   'negosheation',
#   'negoshiationis',
#   'netyotiation',
#   'nigonations',
#   'egosatem',
#   'negostionaion',
#   'negogiation',
#   'negoshishayns',
#   'negoatiations',
#   'negocheations',
#   'negiotiation',
#   'negoshchiations',
#   'negotation',
#   'negotiolations',
#   'negotitations',
#   'neggosionion',
#   'negotions',
#   'negosiation',
#   'neguotiations',
#   'negoseeasion',
#   'agoshion',
#   'negiotations',
#   'negoshiations',
#   'necognitiomtions',
#   'negoitation',
#   'negoceations',
#   'negocations',
#   'negoeations',
#   'degosiations',
#   'ingosheaction',
#   'negocation',
#   'negotiation',
#   'negoation',
#   'negotiatetions',
#   'negosheations',
#   'negociatiances',
#   'negociasions',
#   'negoshation',
#   'negoseations',
#   'negoseciations',
#   'necogiations',
#   'negotians',
#   'negoacations',
#   'negotitions',
#   'negoatation',
#   'nocitin',
#   'negotiatins',
#   'nicociation',
#   'negoations',
#   'negociation',
#   'nogatuation',
#   'negottation',
#   'negioation',
#   'negorislation',
#   'negatiations',
#   'nogationes',
#   'negotionation',
#   'degotuations',
#   'negostions',
#   'negochictions',
#   'negosheaitions',
#   'negoiations',
#   'negotations',
#   'negotition',
#   'negoiation',
#   'negotianations',
#   'negiatations',
#   'negota',
#   'negeoations',
#   'negote',
#   'negotion',
#   'negoti',
#   'negotciations',
#   'agociate',
#   'negogiations',
#   'negogations',
#   'negoodations',
#   'negociations',
#   'negochiations',
#   'negatations',
#   'negociatione',
#   'negosiations'],
#  'floor': ['flor', 'flor', 'foor'],
#  'flood': ['flud', 'flod'],
#  'superfluous': ['superfulous'],
#  'roll': ['rol'],
#  'double-cross': ['double_cross'],
#  'asterisk': ['asterick'],
#  'eminent': ['imanent', 'emminent', 'iminent'],
#  'scale': ['skale'],
#  'rolling': ['roling'],
#  'quandary': ['quandry'],
#  'good-natured': ['good_natured'],
#  'time': ['tiem',
#   'tiem',
#   'timne',
#   'tame',
#   'tim',
#   'tim',
#   'tine',
#   'thim',
#   'thim',
#   'tiome'],
#  'push': ['puch'],
#  'breadth': ['breath'],
#  'cincinnati': ['cincinatti'],
#  'chain': ['chane', 'chan', 'choin'],
#  'whoever': ['who_ever'],
#  'indians': ["indian's"],
#  'integration': ['intergration'],
#  'skate': ['skat'],
#  'chair': ['chere', 'char', 'chiar'],
#  'midst': ['mist'],
#  'ukrainian': ['ukranian'],
#  'philosopher': ['philisopher'],
#  'vet': ['vent',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vethn',
#   'vetin',
#   'vethu'],
#  'amplification': ['amification'],
#  'mache': ['mashe'],
#  'bicycles': ['bycicles', 'bciyle'],
#  'cheap': ['cheep'],
#  'choice': ['chose', 'choise'],
#  'gloomy': ['glooming', 'gloomming', 'glomy'],
#  'break_time': ['breaktime'],
#  'exact': ['exsact'],
#  'minute': ['minuet', 'minite', 'miniute', 'minit'],
#  'tear': ['tair', 'tare'],
#  'leave': ['life',
#   'life',
#   've',
#   'levef',
#   'live',
#   'lefnr',
#   'lever',
#   'leasve',
#   'leav',
#   'leve',
#   'leve'],
#  'settle': ['settel'],
#  'team': ['term', 'teem', 'tem'],
#  'loads': ['loess', 'loades', 'loades'],
#  'prevent': ['pervent'],
#  'spiritual': ['spherical',
#   'speratral',
#   'spitural',
#   'spirisul',
#   'spiritul',
#   'speratual',
#   'pirtral',
#   'spearacher',
#   'speiritually',
#   'spiritually',
#   'spiritural',
#   'spiriturel',
#   'spitrial',
#   'spritural',
#   'speritual',
#   'spirtful',
#   'spirical',
#   'spiritiaul',
#   'spirurel',
#   'spritially',
#   'spuritily',
#   'spitirial',
#   'spritiual',
#   'spertial',
#   'spirchial',
#   'spirt',
#   'spirtial',
#   'spirtual',
#   'spirlial',
#   'spulcure',
#   'spertiaul',
#   'spritule',
#   'spirttual',
#   'sperical',
#   'spirtural',
#   'spirititual',
#   'speartiual',
#   'spirtional',
#   'sprirtual',
#   'spirituall',
#   'spieratually',
#   'spritual',
#   'spcerial',
#   'spirital',
#   'sprital',
#   'sipural',
#   'speratural',
#   'spearitial',
#   'spiritial'],
#  'occurrence': ['occurance',
#   'occurance',
#   'occurrance',
#   'ocurrance',
#   'occurence',
#   'occurence',
#   'occurence',
#   'ocurrence'],
#  'two-faced': ['two_faced'],
#  'attic': ['atic'],
#  'sign': ['sighn', 'eign', 'sion'],
#  'candlestick': ['candle_stick'],
#  'essence': ['essense'],
#  'jeopardy': ['jeapardy', 'jepardy'],
#  'celebrated': ['celebrate'],
#  'melt': ['malt'],
#  'current': ['curent'],
#  'extraterrestrial': ['extraterrestial'],
#  'chrysanthemums': ['chrisanthimums'],
#  'falling': ['folling'],
#  'badge': ['bage'],
#  'jury': ['jurry'],
#  'honour': ['honer'],
#  'funeral': ['funerl', 'funerl', 'funrel'],
#  'understanding': ['understanting', 'undestanding', 'under_standing'],
#  'address': ['adress', 'adress', 'adres', 'addres'],
#  'alone': ['alown', 'a_lone', 'a_lone', 'alon', 'aloun'],
#  'along': ['a_long', 'all', 'aling', 'alog', 'allong'],
#  'my': ['me', 'ma', 'may', 'may', 'mi', 'ne', 'miy', 'ny', 'yoy', 'by'],
#  'momentous': ['momentus'],
#  'financiers': ['fincancers', 'financers'],
#  'dusty': ['duste'],
#  'studied': ['studed', 'studyed'],
#  'wherever': ['whereever', 'whereever', 'wereever', 'where_ever', 'were_ever'],
#  'commonly': ['commongly'],
#  'accomplished': ['aclimplised',
#   'acolpleshed',
#   'comdash',
#   'acomplised',
#   'acombished',
#   'aconplised',
#   'accomplish',
#   'accaplished',
#   'acoplished',
#   'acoumpish',
#   'acaulle',
#   'acomplisht',
#   'acolplished',
#   'aconplish',
#   'acuplished',
#   'acalern',
#   'accomhed',
#   'aconase',
#   'accamplish',
#   'aclomplished',
#   'aco',
#   'acumlished',
#   'apcomplished',
#   'acompilsh',
#   'acomplished',
#   'acomplished',
#   'acomplshed'],
#  'proclamation': ['proclomation'],
#  'studies': ['studys'],
#  'love': ['lveo', 'lvoe', 'loev'],
#  'radish': ['raddish'],
#  'prefer': ['perfuer',
#   'perfour',
#   'preafer',
#   'perer',
#   'prefor',
#   'perfer',
#   'pefer',
#   'perfure',
#   'prefore',
#   'prof',
#   'proe',
#   'profer',
#   'prver',
#   'peair',
#   'perver',
#   'prefur',
#   'brfere',
#   'provere',
#   'perful',
#   'profferr',
#   'prefure',
#   'prefere'],
#  'bloody': ['blody', 'bludy', 'bludy'],
#  'marvelous': ['marvellous', 'marvalous'],
#  "grandpa's": ['grandpas'],
#  'crammed': ['cramp'],
#  'working': ['warking', 'wroking', 'work', 'wokring', 'woking'],
#  'homesick': ['homsick'],
#  'positive': ['positve', 'possitive'],
#  'angry': ['angery', 'angrey'],
#  'dangle': ['dongle'],
#  'predictions': ['pe'],
#  'vigour': ['vigeur'],
#  'wood': ['wod'],
#  'opposed': ['apposed'],
#  'wondering': ['wondring'],
#  'films': ['firms'],
#  'theoretical': ['theridically', 'teridical'],
#  'loving': ['loveing'],
#  'marbles': ['marables', 'marballs'],
#  'afford': ['affort', 'efford', 'aford'],
#  'apparent': ['appreant',
#   'appearent',
#   'parent',
#   'apprarent',
#   'apparant',
#   'apparant',
#   'aparot',
#   'apperant',
#   'aprent',
#   'aparaent',
#   'aperant',
#   'apperent',
#   'aparant',
#   'apprent',
#   'aparent',
#   'aparent',
#   'apparient'],
#  'appendix': ['apendix'],
#  'everywhere': ['everwhere',
#   'eyerwhere',
#   'eveywhere',
#   'every_were',
#   'evry_were'],
#  'virtue': ['vertue',
#   'vurtued',
#   'virchu',
#   'virtu',
#   'verue',
#   'verchew',
#   'vertieu',
#   'vergue',
#   'virteau',
#   'virture',
#   'vurtue',
#   'verterue',
#   'victure',
#   'verters',
#   'vertive',
#   'virtuals',
#   'furtue',
#   'ferture',
#   'verchue',
#   'fertued',
#   'verchu',
#   'virtues',
#   'virtuge',
#   'verture',
#   'vertie',
#   'verchude',
#   'verto',
#   'virtou',
#   'virercut',
#   'fertue',
#   'vertu',
#   'virtrue',
#   'virtiou',
#   'viricheu'],
#  'originally': ['origonly',
#   'orrigalaly',
#   'organial',
#   'orrginally',
#   'originnally',
#   'origienoley',
#   'oringinally',
#   'arridgely',
#   'originial',
#   'arridionally',
#   'origionally',
#   'oridgenally',
#   'oridgenouly',
#   'originially',
#   'oridganaly',
#   'arigionaly',
#   'orriginally',
#   'orignially',
#   'originually',
#   'originality',
#   'orginially',
#   'orriganily',
#   'origially',
#   'oridtionaly',
#   'organially',
#   'organly',
#   'anganally',
#   'ariginaly',
#   'origianally',
#   'orrignally',
#   'eriganally',
#   'oringle',
#   'regularly',
#   'ornanly',
#   'arridgenally',
#   'arigale',
#   'orginaly',
#   'oreginally',
#   'arigionally',
#   'origanilly',
#   'origedenally',
#   'origanily',
#   'orridginally',
# ...
#   'resorse',
#   'resauce',
#   'resourse'],
#  'artist': ['artest'],
#  'parasitic': ['saresitic'],
#  'borrow': ['brow', 'barrow'],
#  'worried': ['woried', 'worid', 'worred', 'worred'],
#  'cochlea': ['ch'],
#  'priest': ['preist'],
#  'bee-keepers': ['bee_keepers'],
#  'bombs': ['bomes', 'boms'],
#  'liable': ['lieable', 'lible', 'lyable'],
#  'worries': ['worre'],
#  'where': ['we',
#   'wee',
#   'wer',
#   'wet',
#   'wart',
#   'there',
#   'werre',
#   'ther',
#   'wher',
#   'gaing',
#   'wuy',
#   'wear',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'were',
#   'whrer',
#   'ware',
#   'with',
#   'war',
#   'hwere',
#   'wir'],
#  'arrival': ['arival', 'arrivial'],
#  'surgery': ['surgere'],
#  'no-one': ['know_one', 'now_one', 'knowone'],
#  'jumped': ['jump', 'jump', 'jump', 'jumb', 'jumpt', 'jumth', 'jumper'],
#  'receivers': ['recievers'],
#  'representatives': ["representative's",
#   'repersenitives',
#   'representiveties',
#   'representive',
#   'represntatives',
#   'represenatives',
#   'repesentatives',
#   'representatives',
#   'represenitives',
#   'repersentives',
#   'repersentitives',
#   'represempative',
#   'represinetives',
#   'representies',
#   'represenitive',
#   'represantives',
#   'represenatives',
#   'represtantives',
#   'repsenatives',
#   'represenitives',
#   'representitives',
#   'repistentives',
#   'representitatives',
#   'repersintives',
#   'repersentaves',
#   'represenetives',
#   'representitive',
#   "representatives'",
#   'represnetatives',
#   'repstinues',
#   'representative',
#   'representivies',
#   "represident's",
#   'repasenatives',
#   'representives',
#   'representives',
#   'respensations',
#   'repersentatives',
#   'repersenatives',
#   'repersentitive',
#   'repersentive',
#   'represenitatives',
#   'repesident'],
#  'dormitory': ['domortory',
#   'dortory',
#   'dormentdory',
#   'dormoratory',
#   'dormiatory',
#   'dorinatory',
#   'domatarily',
#   'dormititory',
#   'durmatory',
#   'dormotory',
#   'dormertory',
#   'doormetory',
#   'doromatory',
#   'dormortory',
#   'dormitly',
#   'domotory',
#   'dormatory',
#   'domatory',
#   'dornoratory',
#   'dormortary',
#   'dormatary',
#   'doormintory',
#   'dormantory',
#   'doramatory',
#   'dormitary',
#   'adormatory',
#   'dormitoriy',
#   'dormentory',
#   'dormotary',
#   'doomator',
#   'dorimatory',
#   'doromortory',
#   'doornitory',
#   'doromitory',
#   'dormintory',
#   'dormenatory',
#   'dormetory',
#   'deormetormy',
#   'dorenatory',
#   'dormadory',
#   'domitory',
#   'dorrmatory',
#   'daumitary',
#   'dommority',
#   'doramtory',
#   'dornatorie',
#   'dooratory',
#   'dormortority',
#   'dormatoraly',
#   'domorotry',
#   'dormontory',
#   'dorimitory',
#   'dormatey',
#   'dormitlory',
#   'doratory',
#   'deomertory',
#   'dormitorrary',
#   'dormiltory',
#   'dorminatory',
#   'dorimtory',
#   'doromority',
#   'dorminty',
#   'domutory',
#   'dormarty',
#   'dominory',
#   'domeritria',
#   'doritory',
#   'domitry',
#   'dominatory',
#   'domteracy'],
#  'kilometer': ['lilometer'],
#  'bureau': ['beauro'],
#  'enjoys': ['enyays'],
#  'cantaloupe': ['cantaloube'],
#  'vertical': ['verticle'],
#  'aberration': ['aberation'],
#  'screen': ['seveen'],
#  'suppresses': ['supresses'],
#  'revealed': ['revealled'],
#  'gratefully': ['greatfully'],
#  'concentrate': ['concetrate',
#   'consuntrate',
#   'consentrate',
#   'consentrate',
#   'consantrate'],
#  'spare': ['shar',
#   'spaip',
#   'spair',
#   'his',
#   'ser',
#   'spear',
#   'sper',
#   'share',
#   'spere',
#   'spu',
#   'ster',
#   'shaper',
#   'score',
#   'spar',
#   'sgre',
#   'sereine'],
#  'in_between': ['inbetween'],
#  'suppressed': ['surpressed', 'supressed'],
#  'concentrated': ['consentrated'],
#  'mans': ['masn'],
#  'many': ['meny', 'meny', 'meay', 'meney', 'memey', 'may', 'manny', 'mony'],
#  "classroom's": ['class_rooms'],
#  'millionaire': ['million_air', 'millionnaire', 'millionere', 'million_ear'],
#  'besieging': ['beseiging'],
#  'personal': ['personly', 'personel', 'personel', 'persnal'],
#  'concentrates': ['consentrates'],
#  'expression': ['expresion'],
#  "can't": ["cann't",
#   'carnt',
#   'carnt',
#   'cant',
#   'cant',
#   'cant',
#   'cant',
#   "carn't",
#   "carn't",
#   'canth'],
#  'allowance': ['allowence'],
#  'yearly': ['yearley'],
#  'twin': ['twen'],
#  'comeback': ['comback'],
#  'geese': ['gees'],
#  'buoyancy': ['bouyancy'],
#  'considers': ['conciders'],
#  'boat': ['boaut', 'bot'],
#  'caring': ['careing'],
#  'comb': ['come'],
#  'unconsciousness': ['unconciousness'],
#  'stretch': ['strech', 'streach'],
#  'west': ['wast'],
#  'locally': ['localy'],
#  'vacation': ['vakation', 'vacashon', 'vaction'],
#  'concede': ['consede'],
#  'breath': ['breathe', 'breth', 'brath'],
#  'almighty': ['almity'],
#  'practised': ['practise', 'practiced'],
#  'wants': ['wans', 'wnats', 'wantes', 'want'],
#  'enable': ['unable', 'anable'],
#  'unsafe': ['unsf'],
#  'thousand': ['thousend', 'thousnand'],
#  'formed': ['fromed', 'form', 'formd'],
#  'observe': ['obsirve', 'obi'],
#  'extant': ['extint'],
#  'calligraphy': ['caligraphy'],
#  'former': ['fro', 'farmer'],
#  'prominence': ['prominance'],
#  'straighten': ['straiten'],
#  'easier': ['eassier', 'ease', 'easyer', 'easy', 'easery', 'easer'],
#  'newspaper': ['newpaper', 'newspapper', 'news_paper'],
#  'situation': ['situration', 'sitt', 'situating'],
#  'constituency': ['consituency'],
#  'all-round': ['all_round'],
#  'purse': ['purce', 'perse'],
#  'vandalism': ['vanderlism', 'vandolism', 'vanderlisium'],
#  'unhygienic': ['unheigenic'],
#  'barbed': ['barb', 'barb'],
#  'sickness': ['sicknes'],
#  'i': ['a',
#   'and',
#   'ld',
#   'we',
#   'i',
#   'is',
#   'it',
#   'iy',
#   'if',
#   'are',
#   'has',
#   'he'],
#  'defy': ['defie'],
#  'advertisement': ['advertisment', 'advertisment'],
#  'volcanoes': ['volcanos'],
#  'vacant': ['vacent'],
#  'tentacle': ['tenacle'],
#  'so_forth': ['soforth', 'so-forth'],
#  'genii': ['genei'],
#  'grumpy': ['grumby'],
#  'botswana': ['botuania'],
#  'summer': ['sumer'],
#  'manifold': ['many_fold'],
#  'being': ['bieng', 'be', 'bi', 'been', 'been', 'bieing', 'beeing'],
#  'truculent': ['trucculent'],
#  'exaggerating': ['exagerating', 'exagerrating'],
#  'rest': ['rast'],
#  'schools': ['school', 'schol'],
#  'steamer': ['stemer'],
#  'omissions': ['ommissions'],
#  'weekly': ['weakly'],
#  'sixteen': ['sixtine', 'sixten'],
#  'generator': ['generrater'],
#  'silver': ['siver', 'sliver'],
#  'instrument': ['instrement', 'instrment', 'insromet', 'instriment'],
#  'prominently': ['prominately', 'prominantly'],
#  'aspects': ['spects'],
#  'around': ['rand',
#   'arr',
#   'rend',
#   'a_rand',
#   'aradret',
#   'ar',
#   'a_rade',
#   'roned',
#   'arouned',
#   'ar_rounde',
#   'a_rarnd',
#   'rond',
#   'aroand',
#   'aron',
#   'aroud',
#   'arond',
#   'arround',
#   'arad',
#   'a_round',
#   'a_round',
#   'a_rond',
#   'arode',
#   'urand',
#   'aroude',
#   'arownd',
#   'round'],
#  'decomposed': ['decomposited'],
#  'knobbly': ['nobbly'],
#  'dart': ['tat',
#   'art',
#   'darrt',
#   'doatg',
#   'darte',
#   'derter',
#   'brt',
#   'dered',
#   'daud',
#   'yaht',
#   'dorte',
#   'dute',
#   'drate',
#   'dete',
#   'durt',
#   'daring',
#   'darolt',
#   'byt',
#   'drte',
#   'snad',
#   'daet',
#   'doath',
#   'dutr',
#   'dard',
#   'dut',
#   'dunt',
#   'tart',
#   'dae',
#   'dert',
#   'burte',
#   'dirt',
#   'dorter',
#   'deent',
#   'but',
#   'dret',
#   'dat',
#   'drek',
#   'daw',
#   'nitty',
#   'datre',
#   'deatre',
#   'date',
#   'bit',
#   'deart',
#   'drat',
#   'dater',
#   'drit',
#   'adar',
#   'derdt',
#   'drt',
#   'dared',
#   'snt',
#   'drk',
#   'dort',
#   'duit',
#   'durte',
#   'dot'],
#  'dark': ['ding',
#   'duc',
#   'durk',
#   'dake',
#   'back',
#   'ducr',
#   'dia',
#   'down',
#   'drlak',
#   'dick',
#   'barck',
#   'dining',
#   'dork',
#   'dagy',
#   'drck',
#   'drak',
#   'darrk',
#   'darw',
#   'dak',
#   'dreh',
#   'brek',
#   'dare',
#   'dard',
#   'bar',
#   'drow',
#   'dog',
#   'drk',
#   'dank',
#   'bnack',
#   'darch',
#   'darck',
#   'darck',
#   'dir'],
#  'traffic': ['travic',
#   'tacter',
#   'drafec',
#   'trafice',
#   'trafick',
#   'traffi',
#   'trofek',
#   'trafeck',
#   'tavit',
#   'trfick',
#   'traie',
#   'tatif',
#   'tiornef',
#   'tac',
#   'roads',
#   'tarnftian',
#   'peraffic',
#   'cafic',
#   'treffer',
#   'trafit',
#   'trafic',
#   'trafic',
#   'tafic',
#   'tavek',
#   'taafic',
#   'tiatic',
#   'taame',
#   'trafack',
#   'tatlek',
#   'tafeate',
#   'traffek',
#   'trafik',
#   'traffc',
#   'trafet',
#   'traveck',
#   'track',
#   'traff',
#   'traffig',
#   'tairer',
#   'traffice',
#   'tinict',
#   'traik',
#   'travick',
#   'tracky',
#   'traifec',
#   'terrec',
#   'traffik',
#   'trafek',
#   'tarffic',
#   'taveging',
#   'tafter',
#   'taraf',
#   'craffeck',
#   'tale',
#   'tate',
#   'thaiech',
#   'farolc',
#   'trare',
#   'traph',
#   'trafec'],
#  'bandage': ['bandge'],
#  'vacuum': ['vaccume', 'vaccum'],
#  'world': ['wald', 'worde', 'word', 'would', 'wholed', 'wold', 'wourld'],
#  'postal': ['postel'],
#  'decomposes': ['decomposits'],
#  'vague': ['vaig', 'vage'],
#  'dare': ['dear', 'dair'],
#  'satisfaction': ['shasan',
#   'satichfatshen',
#   'satisfacshoin',
#   'satisfacshion',
#   'wanat',
#   'sabfas',
#   'istis',
#   'satisfacshin',
#   'satisfashoin',
#   'satisfacsion',
#   'satfacso',
#   'sachfachn',
#   'stisfacho',
#   'satlistash',
#   'satisfacion',
#   'satesfaction',
#   'satisfation',
#   'satiusfacson',
#   'satifacian',
#   'satefasion',
#   'satisfactoin',
#   'satifoin',
#   'satishfacen',
#   'satisfaften',
#   'satfaction',
#   'sackaach',
#   'satfakess',
#   'satifactoin',
#   'saciffaction',
#   'satfacan',
#   'satisfacttion',
#   'satamachen',
#   'satishfation',
#   'silhen_fant',
#   'sacfatchen',
#   'satesfach_chere',
#   'satisfn',
#   'satirsh',
#   'siterfatur',
#   'satisfatch',
#   'eat_as_of_ede',
#   'satishfaction',
#   'satisfakshion',
#   'fian',
#   'satisfacshon',
#   'satifation',
#   'setisfate',
#   'satifachen',
#   'satishfaktion',
#   'satifishan',
#   'satitfaction',
#   'sat_oford',
#   'sartfasn',
#   'sats_fan',
#   'satisvetion',
#   'satisfacshun',
#   'satfasher',
#   'sicifaris',
#   'setitfared',
#   'sitisfaction',
#   'satisfuckshon',
#   'satishan',
#   'sat_fainand',
#   'sachen',
#   'sachfaen',
#   'statsiefacsed',
#   'argring_atoing',
#   'satigan',
#   'satichfachcen',
#   'satisfachan',
#   'satiffashon',
#   'sacisfacsh',
#   'satisfakson',
#   'satisfackshen',
#   'sackitvansh',
#   'satifaction',
#   'satifachon',
#   'satisfachen',
#   'soam',
#   'sackifsacshern',
#   'sattfashed',
#   'satsha',
#   'satifason',
#   'satispachoin',
#   'saticfacon',
#   'satisfakshon',
#   'satisfacin',
#   'call_fall',
#   'satisfcshion',
#   'satifacion',
#   'satistloin',
#   'satigaction',
#   'satisfackshon',
#   'satesfacshen',
#   'satisfachshon',
#   'satfatre',
#   'satisfain'],
#  'unrepentant': ['unrepentent'],
#  'nutrients': ['nutritents'],
#  'souvenirs': ['souveniers'],
#  'discarded': ['discare'],
#  'stationary': ['stationery'],
#  'clap': ['klap', 'clape'],
#  'auditorium': ['autorm',
#   'autoruim',
#   'auditormunen',
#   'audiatorum',
#   'auditouim',
#   'allturman',
#   'audatoreum',
#   'oratoroum',
#   'autitorium',
#   'auditorm',
#   'additorium',
#   'auditorim',
#   'autormen',
#   'allortomdd',
#   'audaterame',
#   'adutorium',
#   'auditarium',
#   'auditory',
#   'attorium',
#   'audetorium',
#   'audotorium',
#   'auditourin',
#   'auditorial',
#   'auditoriam',
#   'autorum',
#   'auditoruium',
#   'autotorium',
#   'autatorum',
#   'autatorom',
#   'adetoreum',
#   'aduoteriam',
#   'auditorinum',
#   'audatorum',
#   'auttortism',
#   'auditiorm',
#   'audortum',
#   'ouditorium',
#   'auditorum',
#   'auditoium',
#   'auditoryum',
#   'auditoriom',
#   'auditorimn',
#   'adatorum',
#   'auditorym',
#   'arudtiorze',
#   'auditormeon',
#   'auditorumen',
#   'authorium',
#   'auditoreum',
#   'ottatorium',
#   'audiotorium',
#   'autitorum',
#   'audiortium',
#   'attoram',
#   'audetorn',
#   'auditor',
#   'audatorium',
#   'audortorium',
#   'auditoriumn',
#   'aduitorum',
#   'auditoriun',
#   'aditorum',
#   'aditorium'],
#  'satisfactory': ['satsfactory', 'satifactory', 'satisfactary'],
#  'superintendent': ['superintendant', 'supertendent'],
#  'learning': ['learnning', 'learing', 'lerning', 'learining'],
#  'supplementary': ['suplementary'],
#  'divine': ['devin',
#   'devying',
#   'divide',
#   'deavine',
#   'devide',
#   'devine',
#   'devined',
#   'delvine',
#   'divene',
#   'define'],
#  'thinks': ['thikns'],
#  "there'll": ['therell'],
#  'memories': ['memoirs',
#   'mearise',
#   'memeroies',
#   'momories',
#   'memerories',
#   'meherey',
#   'merrerys',
#   'memoaries',
#   'memoraries',
#   'merries',
#   'mermarys',
#   'mermories',
#   "memory's",
#   'remison',
#   'memordies',
#   'memorries',
#   'mearsise',
#   'memey',
#   'memory',
#   'memoiries',
#   'memuries',
#   'memoreys',
#   'merrors',
#   'memmories',
#   'moniiy',
#   'monorious',
#   'merories',
#   'memeris',
#   'merores',
#   'moremery',
#   'memoreres',
#   'marysis',
#   'memoryes',
#   'memorarys',
#   'memouries',
#   "memorie's",
#   'memorys',
#   'memeries',
#   'mermiores',
#   'memmorys',
#   'memerys',
#   'mamrioes'],
#  'noon': ['non'],
#  'endocrine': ['endochrine'],
#  'refer': ['refere'],
#  'unsuccessfully': ['unsucesfuly', 'unsucessfully'],
#  'accessing': ['accesing'],
#  'scientific': ['scientic', 'scienfic', 'st'],
#  'power': ['pwoer', 'pour'],
#  'intimate': ['intermit'],
#  'in_spite': ['inspite'],
#  'playing-field': ['playfud', 'playing_field', 'playfeild'],
#  'stone': ['ston'],
#  'package': ['packege', 'pakage'],
#  'disabilities': ['dissabiliteys'],
#  'meal': ['mel', 'mell'],
#  'neighbor': ['neighbour', 'neigbour'],
#  'act': ['at', 'akt'],
#  'luck': ['lock'],
#  'rabbinical': ['rabinnical'],
#  'burning': ['buring'],
#  'legged': ['leged'],
#  'lively': ['livly', 'livley'],
#  'parties': ['partys', "party's"],
#  'accumulated': ['acumulated'],
#  'technically': ['technecally', 'techniquely'],
#  'burglar': ['burgler', 'buglar'],
#  'her': ['here'],
#  'series': ['serious'],
#  'water-rat': ['waterrat'],
#  'bubble': ['buble'],
#  'yearned': ['yerned'],
#  'complete': ['compleat'],
#  'beginners': ['begginers'],
#  'elimination': ['eleimination', 'elimiation'],
#  'impedance': ['impedence', 'impedence'],
#  'mice': ['mise'],
#  'with': ['whin',
#   'wif',
#   'wefe',
#   'wis',
#   'wis',
#   'in',
#   'whit',
#   'iwth',
#   'wihth',
#   'wiy',
#   'will',
#   'what',
#   'wef',
#   'wien',
#   'when',
#   'wthe',
#   'whith',
#   'wethe',
#   'wivr',
#   'we',
#   'wihe',
#   'wh',
#   'wite',
#   'wiht',
#   'wiht',
#   'wiht',
#   'wive',
#   'wirth',
#   'went',
#   'wtih',
#   'withe',
#   'wint',
#   'weth',
#   'wit',
#   'yethe',
#   'witht',
#   'the',
#   'wheth'],
#  'buying': ['buyin', 'bying'],
#  'handsome': ['hansem', 'hansum', 'hansome'],
#  "they're": ['their', 'the', 'there', 'there', 'thier'],
#  'rush': ['ruch'],
#  'monopoly': ['monapaloy'],
#  'dirty': ['dertses', 'diry', 'driy', 'durty'],
#  'dispensing': ['dispencing'],
#  'agree': ['agre', 'agre'],
#  'detailed': ['detailled', 'detailled'],
#  'gone': ['gon',
#   'gon',
#   'crome',
#   'gome',
#   'goon',
#   'gonne',
#   'gornd',
#   'go',
#   'go',
#   'go',
#   'gor'],
#  'gratuitous': ['gratuitious'],
#  'exhausted': ['exausted', 'exhasted', 'exa'],
#  'certain': ['sorton',
#   'certian',
#   'surntered',
#   'sirtain',
#   'ceratin',
#   'curtain',
#   'sertain',
#   'cirtain',
#   'serton'],
#  'accents': ['achsends'],
#  'cinderella': ['cinderrella'],
#  'am': ['ham', 'an'],
#  'an': ['a', 'a', 'and', 'and', 'un', 'am', 'on'],
#  'as': ['ass',
#   'a',
#   'his',
#   'asw',
#   'have',
#   'was',
#   'hase',
#   'is',
#   'tes',
#   'at',
#   'aas',
#   'has',
#   'has',
#   'saw',
#   'als'],
#  'at': ['a', 'a', 'a', 'ast', 'al', 'an', 'as', 'are', 'are', 'att'],
#  'hobbies': ['hobbys'],
#  'creak': ['creek'],
#  'cream': ['crem'],
#  'ideally': ['idealy'],
#  'graduate': ['graguate'],
#  'tight': ['tite'],
#  'watson': ['watston'],
#  'unparalleled': ['umparralled',
#   'unparralel',
#   'unparalleld',
#   'unparallelled',
#   'unparlleled',
#   'parrealled',
#   'apparrelled',
#   'unparralleled',
#   'unparreled',
#   'unparielled',
#   'empalerleld',
#   'uparrelled',
#   'unparalled',
#   'unplaled',
#   'unparlled',
#   'unparallel',
#   'anparelle',
#   'unparelled',
#   'unpall',
#   'unparrelede',
#   'un-parrallel',
#   'unblale',
#   'unparale',
#   'unperalld',
#   'unparalel',
#   'unparrowllede',
#   'unparolled',
#   'unparalelled',
#   'unparaled',
#   'unpovaly',
#   'unparralled',
#   'unparraled',
#   'unparrallel',
#   'unparrled',
#   'unpareled',
#   'unapparralled',
#   'unparraleled',
#   'unparelelled',
#   'unparrelled',
#   'unparelleled',
#   'andpiotou',
#   'unproloud'],
#  'puppy': ['pupy'],
#  'contemporaries': ['contamporaries'],
#  'congress': ['converce',
#   'curgress',
#   'congress',
#   'converse',
#   'cnongress',
#   'cangress',
#   'congres',
#   'comgress',
#   'congeres'],
#  'spermatozoa': ['spermatozoan'],
#  'tiger': ['tigar'],
#  'partitioned': ['petitioned'],
#  'mask': ['mast', 'masked', 'marsk'],
#  'having': ['haveing', 'haveing', 'hvaing', 'have-ing', 'hower'],
#  'impossibility': ['impossibilty'],
#  ...}

# %%
from itertools import zip_longest
def difference_of_words(word_true, word_mistake):
    # returns mistake type, mistake made and intended letters
    one_step_compare = zip_longest(word_true, word_mistake,
                                   word_true[1:], word_mistake[1:],
                                   ' '+word_true, ' '+word_mistake,
                                   fillvalue='')
    for char_true, char_false, char_true_ahead, char_false_ahead, char_true_prev, char_false_prev in one_step_compare:
        if char_true != char_false:
                # transposition
                if (char_true_ahead == char_false) & (char_false_ahead == char_true):
                    return({'type':'transposition', 'error': char_false + char_false_ahead,
                           'true': char_true + char_true_ahead})
                # substitution
                elif (char_true_ahead == char_false_ahead)\
                    &(len(word_true)==len(word_mistake)):
                    return({'type':'substitution', 'error': char_false,'true': char_true})
                # deletion
                elif char_true_ahead == char_false:
                    if char_false != '':
                        return({'type':'deletion', 'error':char_false,
                                'true': char_true + char_true_ahead})
                    else:
                        return({'type':'deletion', 'error':char_false_prev,
                                'true': char_true_prev + char_true})
                # insertion
                elif char_false_ahead == char_true:
                    if char_true != '':
                        return({'type':'insertion', 'error':char_false + char_false_ahead,
                                'true': char_true})
                    else:
                        return({'type':'insertion', 'error':char_false_prev + char_false,
                                'true': char_true_prev})

# %%
difference_of_words('thers', 'therss')
# Out:
# {'error': 'ss', 'true': 's', 'type': 'insertion'}

# %%
from collections import defaultdict
def get_confusion_matrix(mispelled_dict):
    mistake_count  = defaultdict(int)
    type_count     = defaultdict(int)
    agg_by_mistake = defaultdict(int)
    for key, val in mispelled_dict.items():
        for mispelled_word in val:
            mistake = difference_of_words(key, mispelled_word)
            if mistake:
                type_count[mistake['type']] += 1
                mistake_count[(mistake['error'],mistake['true'])] +=1
                agg_by_mistake[mistake['true']] += 1
    return(type_count, mistake_count, agg_by_mistake)

# %%
type_count, mistake_count, agg_by_mistake = get_confusion_matrix(mispelled_dict)

# %%
sorted(mistake_count.items(), key=lambda x: x[1], reverse = True)
# Out:
# [(('e', 'i'), 647),
#  (('a', 'e'), 583),
#  (('', 'ed'), 535),
#  (('e', 'a'), 508),
#  (('i', 'e'), 488),
#  (('', 'ly'), 387),
#  (('s', 'c'), 322),
#  (('a', 'i'), 305),
#  (('l', 'al'), 284),
#  (('e', 'ie'), 266),
#  (('a', 'o'), 246),
#  (('o', 'a'), 240),
#  (('s', 'es'), 236),
#  (('u', 'ou'), 232),
#  (('l', 'el'), 228),
#  (('c', 'sc'), 224),
#  (('ie', 'e'), 218),
#  (('r', 'ar'), 218),
#  (('y', 'ly'), 205),
#  (('n', 'in'), 196),
#  (('e', 'ce'), 186),
#  (('d', 'ed'), 185),
#  (('e', 'he'), 185),
#  (('n', 'm'), 184),
#  (('a', 'ia'), 183),
#  (('e', 'o'), 178),
#  (('r', 'ur'), 176),
#  (('t', 'it'), 174),
#  (('e', 'me'), 174),
#  (('c', 's'), 171),
#  (('', 'ng'), 168),
#  (('e', 're'), 168),
#  (('i', 'a'), 168),
#  (('ea', 'a'), 166),
#  (('r', 'er'), 165),
#  (('a', 'ua'), 163),
#  (('a', 'ra'), 160),
#  (('t', 'at'), 158),
#  (('n', 'en'), 156),
#  (('t', 'nt'), 154),
#  (('a', 'la'), 147),
#  (('i', 'hi'), 144),
#  (('ar', 'r'), 139),
#  (('es', 's'), 137),
#  (('ou', 'u'), 137),
#  (('e', 'u'), 136),
#  (('ei', 'i'), 135),
#  (('o', 'u'), 135),
#  (('er', 'r'), 134),
#  (('ey', 'y'), 133),
#  (('e', 'le'), 132),
#  (('', 'us'), 132),
#  (('s', 'us'), 130),
#  (('a', 'ea'), 129),
#  (('i', 'ti'), 129),
#  (('r', 'pr'), 127),
#  (('ur', 'r'), 127),
#  (('i', 'ci'), 127),
#  (('er', 're'), 126),
#  (('i', 'ri'), 126),
#  (('t', 'rt'), 124),
#  (('al', 'l'), 124),
#  (('e', 'te'), 123),
#  (('nt', 't'), 120),
#  (('ei', 'ie'), 118),
#  (('t', 'te'), 118),
#  (('t', 'st'), 118),
#  (('te', 'e'), 117),
#  (('l', 'il'), 116),
#  (('re', 'er'), 116),
#  (('o', 'e'), 115),
#  (('en', 'n'), 114),
#  (('rt', 't'), 109),
#  (('r', 're'), 108),
#  (('u', 'e'), 107),
#  (('n', 'an'), 107),
#  (('ll', 'l'), 106),
#  (('', 'on'), 105),
#  (('n', 'un'), 105),
#  (('', 'nt'), 105),
#  (('i', 'y'), 105),
#  (('e', 'ed'), 105),
#  (('a', 'ha'), 104),
#  (('o', 'ro'), 102),
#  (('s', 'is'), 101),
#  (('n', 'on'), 101),
#  (('el', 'le'), 101),
#  (('si', 'i'), 101),
#  (('m', 'n'), 99),
#  (('o', 'io'), 99),
#  (('', 'es'), 98),
#  (('st', 't'), 97),
#  (('k', 'ck'), 97),
#  (('ti', 'i'), 96),
#  (('a', 'u'), 96),
#  (('in', 'n'), 95),
#  (('o', 'ho'), 95),
#  (('ed', ''), 95),
#  (('hi', 'i'), 94),
#  (('t', 'ut'), 93),
#  (('u', 'o'), 92),
#  (('ia', 'a'), 92),
#  (('le', 'el'), 92),
#  (('at', 't'), 92),
#  (('', 'te'), 91),
#  (('ed', 'd'), 90),
#  (('me', 'em'), 90),
#  (('i', 'si'), 89),
#  (('ra', 'a'), 89),
#  (('', 'ce'), 88),
#  (('ha', 'a'), 87),
#  (('u', 'i'), 87),
#  (('t', 'et'), 87),
#  (('', 'er'), 87),
#  (('rm', 'm'), 83),
#  (('ro', 'or'), 82),
#  (('i', 'u'), 82),
#  (('d', 'nd'), 82),
#  (('e', 'es'), 82),
#  (('y', 'i'), 82),
#  (('un', 'n'), 81),
#  (('_', '-'), 80),
#  (('sc', 'c'), 80),
#  (('in', 'ni'), 80),
#  (('e', 'pe'), 79),
#  (('ie', 'ei'), 79),
#  (('ck', 'k'), 78),
#  (('u', 'a'), 78),
#  (('r', 'ir'), 78),
#  (('', 'le'), 78),
#  (('r', 'or'), 76),
#  (('e', 'y'), 76),
#  (('', 'al'), 75),
#  (('s', "'s"), 75),
#  (('on', 'n'), 74),
#  (('dg', 'g'), 74),
#  (('i', 'fi'), 74),
#  (('ir', 'r'), 73),
#  (('e', 'ge'), 73),
#  (('li', 'i'), 72),
#  (('an', 'n'), 72),
#  (('o', 'co'), 71),
#  (('n', 'rn'), 71),
#  (('ti', 'it'), 71),
#  (('i', 'li'), 70),
#  (('d', 't'), 70),
#  (('p', 'sp'), 69),
#  (('o', 'i'), 69),
#  (('i', 'ni'), 69),
#  (('i', 'ai'), 68),
#  (('s', 'as'), 68),
#  (('te', 't'), 68),
#  (('or', 'r'), 67),
#  (('', 'ry'), 67),
#  (('co', 'o'), 67),
#  (('ra', 'ar'), 67),
#  (('s', 'ce'), 67),
#  (('re', 'e'), 66),
#  (('', 're'), 65),
#  (('ly', 'y'), 64),
#  (('d', 'id'), 64),
#  (('as', 's'), 63),
#  (('rs', 's'), 63),
#  (('he', 'e'), 63),
#  (('o', 'lo'), 63),
#  (('n', 'gn'), 63),
#  (('s', 'ps'), 63),
#  (('l', 'ul'), 62),
#  (('', 'nd'), 62),
#  (('c', 'ac'), 61),
#  (('t', 'd'), 61),
#  (('m', 'em'), 61),
#  (('_s', 's'), 61),
#  (('g', 'dg'), 61),
#  (('ir', 'ri'), 60),
#  (('rn', 'n'), 60),
#  (('n', 'kn'), 60),
#  (('a', 'ta'), 60),
#  (('m', 'um'), 60),
#  (('e', 'ne'), 59),
#  (('si', 'is'), 59),
#  (('ri', 'i'), 59),
#  (('le', 'e'), 58),
#  (('io', 'o'), 58),
#  (('el', 'l'), 58),
#  (('y', 'ry'), 58),
#  (('rl', 'l'), 58),
#  (('', 'ht'), 57),
#  (('or', 'ro'), 57),
#  (('i', 'o'), 56),
#  (('', 'ul'), 56),
#  (('it', 't'), 56),
#  (('r', 'l'), 55),
#  (('ce', 'e'), 55),
#  (('i', 'ei'), 55),
#  (('ho', 'o'), 54),
#  (('se', 'e'), 54),
#  (('f', 'sf'), 54),
#  (('n', 'ne'), 54),
#  (('t', 'ct'), 54),
#  (('i', 'mi'), 54),
#  (('es', 'se'), 54),
#  (('c', 'nc'), 53),
#  (('m', 'am'), 53),
#  (('u', 'au'), 53),
#  (('t', 'ts'), 53),
#  (('c', 'ic'), 53),
#  (('et', 't'), 53),
#  (('a', 'na'), 53),
#  (('t', "'t"), 52),
#  (('ly', ''), 52),
#  (('se', 'es'), 52),
#  (('o', 'no'), 52),
#  (('', 'ts'), 52),
#  (('re', 'r'), 51),
#  (('fi', 'i'), 51),
#  (('sp', 'p'), 50),
#  (('ni', 'i'), 50),
#  (('a', 'ca'), 50),
#  (('o', 'po'), 50),
#  (('w', 'u'), 50),
#  (('ni', 'in'), 49),
#  (('_c', 'c'), 49),
#  (('s', 'rs'), 48),
#  (('ct', 't'), 48),
#  (('e', 'se'), 48),
#  (('il', 'l'), 48),
#  (('s', 't'), 47),
#  (('na', 'a'), 47),
#  (('_b', 'b'), 47),
#  (('de', 'ed'), 46),
#  (('ng', ''), 46),
#  (('au', 'ua'), 46),
#  (('mi', 'i'), 46),
#  (('ia', 'ai'), 46),
#  (('s', 'se'), 46),
#  (('ne', 'n'), 46),
#  (('sa', 'a'), 45),
#  (('ic', 'ci'), 45),
#  (('ul', 'l'), 45),
#  (('c', 'tc'), 45),
#  (('k', 'c'), 44),
#  (('ci', 'i'), 44),
#  (('i', 'yi'), 44),
#  (('', "'s"), 44),
#  (('g', 'ag'), 43),
#  (('', 'ic'), 43),
#  (('t', 'c'), 43),
#  (('l', 'pl'), 43),
#  (('es', ''), 42),
#  (('u', 'w'), 42),
#  (('ue', 'e'), 42),
#  (('', 'ns'), 42),
#  (('g', 'ng'), 42),
#  (('cq', 'q'), 42),
#  (('us', 's'), 42),
#  (('t', 'ht'), 42),
#  (('n', 'ng'), 41),
#  (('it', 'ti'), 41),
#  (('t', 'ed'), 41),
#  (('ai', 'i'), 41),
#  (('e', 'fe'), 41),
#  (('v', 'iv'), 41),
#  (('ar', 'ra'), 41),
#  (('m', 'rm'), 41),
#  (('im', 'm'), 40),
#  (('s', 'ss'), 40),
#  (('na', 'an'), 40),
#  (('c', 't'), 40),
#  (('c', 'g'), 40),
#  (('ro', 'o'), 40),
#  (('e', 'ue'), 40),
#  (('m', 'om'), 40),
#  (('d', 'ad'), 40),
#  (('em', 'me'), 40),
#  (('nd', 'd'), 39),
#  (('am', 'm'), 39),
#  (('l', 'le'), 39),
#  (('i', 'ui'), 39),
#  (('ie', 'y'), 38),
#  (('on', ''), 38),
#  (('c', 'rc'), 38),
#  (('ed', 'e'), 37),
#  (('rc', 'c'), 37),
#  (('s', 'ns'), 37),
#  (('ne', 'en'), 37),
#  (('u', 'cu'), 37),
#  (('tc', 'c'), 36),
#  (('se', 's'), 36),
#  (('n', 'ns'), 36),
#  (('p', 'b'), 36),
#  (("'s", 's'), 35),
#  (('m', 'im'), 35),
#  (('o', 'mo'), 35),
#  (('ui', 'i'), 35),
#  (('p', 'op'), 35),
#  (('a', 'pa'), 35),
#  (('u', 'hu'), 35),
#  (('ac', 'c'), 34),
#  (('l', 'tl'), 34),
#  (('is', 's'), 34),
#  (('es', 'e'), 34),
#  (('u', 'tu'), 34),
#  (('l', 'bl'), 34),
#  (('_t', 't'), 34),
#  (('ng', 'g'), 33),
#  (('s', 'z'), 33),
#  (('nc', 'c'), 33),
#  (('m', 'sm'), 33),
#  (('an', 'na'), 33),
#  (('b', 'd'), 33),
#  (('us', ''), 33),
#  (('r', 'cr'), 33),
#  (('l', 'ol'), 32),
#  (('ed', 'de'), 32),
#  (('de', 'd'), 32),
#  (('o', 'eo'), 32),
#  (('t', 'lt'), 32),
#  (('m', 'me'), 32),
#  (('eu', 'u'), 32),
#  (('um', 'm'), 31),
#  (('th', 'ht'), 31),
#  (('r', 'tr'), 31),
#  (('r', 'u'), 31),
#  (('h', 'ch'), 31),
#  (('q', 'cq'), 31),
#  (('li', 'il'), 31),
#  (('', 'cy'), 31),
#  (('u', 'ru'), 30),
#  (('em', 'm'), 30),
#  (('ec', 'c'), 30),
#  (('te', 'et'), 30),
#  (('r', 'wr'), 30),
#  (('e', 'l'), 30),
#  (('u', 'eu'), 30),
#  (('fe', 'e'), 30),
#  (('y', 'e'), 30),
#  (('_m', 'm'), 30),
#  (('d', 'od'), 30),
#  (('s', 'os'), 30),
#  (('im', 'mi'), 30),
#  (('l', 'hl'), 30),
#  (('g', 'tg'), 30),
#  (('b', 'p'), 29),
#  (('ca', 'a'), 29),
#  (('ri', 'ir'), 29),
#  (('b', 'ab'), 29),
#  (('le', 'l'), 29),
#  (('n', 'hn'), 29),
#  (('is', 'si'), 28),
#  (('t', 'e'), 28),
#  (('l', 'll'), 28),
#  (('er', ''), 28),
#  (('', 'ue'), 28),
#  (('_w', 'w'), 28),
#  (('t', 'pt'), 28),
#  (('ol', 'l'), 28),
#  (('f', 'v'), 28),
#  (('ne', 'e'), 27),
#  (('en', 'ne'), 27),
#  (('eo', 'o'), 27),
#  (('me', 'e'), 27),
#  (('ss', 's'), 27),
#  (('d', 'b'), 27),
#  (('ad', 'd'), 27),
#  (('v', 'f'), 27),
#  (('', 'an'), 27),
#  (('yi', 'i'), 27),
#  (('p', 'ip'), 27),
#  (('o', 'to'), 27),
#  (('y', 'ey'), 27),
#  (('ae', 'ea'), 27),
#  (('e', 's'), 27),
#  (('p', 'ep'), 27),
#  (('', 'ld'), 27),
#  (('c', 'ec'), 27),
#  (('ai', 'ia'), 27),
#  (('er', 'e'), 26),
#  (('ve', 'e'), 26),
#  (('', 'sm'), 26),
#  (('d', 'de'), 26),
#  (('d', 'ld'), 26),
#  (('_n', 'n'), 26),
#  (('la', 'al'), 26),
#  (('p', 'mp'), 26),
#  (('pi', 'i'), 26),
#  (('n', 'wn'), 26),
#  (('o', 'ao'), 26),
#  (('e', 'we'), 26),
#  (('ol', 'lo'), 25),
#  (('et', 'te'), 25),
#  (('n', 'r'), 25),
#  (('i', 'di'), 25),
#  (('s', 'e'), 25),
#  (('p', 'rp'), 25),
#  (('d', 'rd'), 25),
#  (('_g', 'g'), 25),
#  (('a', 'ma'), 24),
#  (('e', 'h'), 24),
#  (('ci', 'ic'), 24),
#  (('z', 's'), 24),
#  (('me', 'm'), 24),
#  (('au', 'u'), 24),
#  (('g', 'ge'), 24),
#  (('kn', 'n'), 24),
#  (('nm', 'm'), 24),
#  (('e', 'ht'), 24),
#  (('_r', 'r'), 24),
#  (('at', 'ta'), 24),
#  (('l', 'r'), 24),
#  (('ng', 'gn'), 24),
#  (('', 'gh'), 24),
#  (('', 'ar'), 24),
#  (('h', 'i'), 23),
#  (('l', 'wl'), 23),
#  (('wo', 'o'), 23),
#  (('h', 'wh'), 23),
#  (('rf', 'f'), 23),
#  (('l', 't'), 23),
#  (('r', 'e'), 23),
#  (('r', 'rs'), 23),
#  (('t', 's'), 23),
#  (('r', 'f'), 23),
#  (('ta', 'at'), 22),
#  (('lo', 'ol'), 22),
#  (('ef', 'f'), 22),
#  (('r', 'i'), 22),
#  (('e', 've'), 22),
#  (('v', 've'), 22),
#  (('al', ''), 22),
#  (('ut', 't'), 22),
#  (('', 'ty'), 22),
#  (('f', 'ef'), 22),
#  (('e', 't'), 22),
#  (('l', 'dl'), 22),
#  (('f', 'rf'), 22),
#  (('o', 'ow'), 21),
#  (('ry', 'y'), 21),
#  (('ry', ''), 21),
#  (('u', 'l'), 21),
#  (('f', 'ff'), 21),
#  (('g', 'j'), 21),
#  (('hn', 'n'), 21),
#  (('r', 'w'), 21),
#  (('e', 'de'), 21),
#  (('_o', 'o'), 21),
#  (('os', 's'), 21),
#  (('ua', 'a'), 21),
#  (('p', 'ap'), 21),
#  (('o', 'oo'), 21),
#  (('o', 'ko'), 21),
#  (('bi', 'ib'), 21),
#  (('y', 'sy'), 20),
#  (('g', 'ug'), 20),
#  (('pe', 'p'), 20),
#  (('r', 'n'), 20),
#  (('om', 'm'), 20),
#  (('lt', 't'), 20),
#  (('r', 'a'), 20),
#  (('c', 'k'), 20),
#  (('al', 'la'), 20),
#  (('ta', 'a'), 20),
#  (('il', 'li'), 20),
#  (('n', 't'), 20),
#  (('la', 'a'), 20),
#  (('de', 'e'), 20),
#  (('t', 'p'), 20),
#  (('k', 'lk'), 20),
#  (('a', 'sa'), 20),
#  (('', 'um'), 20),
#  (('u', 'mu'), 20),
#  (('m', 'nm'), 20),
#  (('mp', 'p'), 20),
#  (('hr', 'r'), 19),
#  (('th', 'h'), 19),
#  (('t', 'ot'), 19),
#  (('e', 'er'), 19),
#  (('iy', 'y'), 19),
#  (('lf', 'f'), 19),
#  (('lo', 'o'), 19),
#  (('b', 'mb'), 19),
#  (('af', 'f'), 19),
#  (('d', 'g'), 19),
#  (('e', 'r'), 19),
#  (('_f', 'f'), 19),
#  (('oi', 'i'), 19),
#  (('nt', ''), 19),
#  (('po', 'o'), 19),
#  (('', 'ch'), 19),
#  (('_h', 'h'), 19),
#  (('uo', 'ou'), 18),
#  (('x', 'c'), 18),
#  (('t', 'l'), 18),
#  (('s', 'ts'), 18),
#  (('t', 'h'), 18),
#  (('h', 'th'), 18),
#  (('hu', 'u'), 18),
#  (('ru', 'ur'), 18),
#  (('l', 'i'), 18),
#  (('ou', 'uo'), 18),
#  (('pe', 'e'), 18),
#  (('_p', 'p'), 18),
#  (('g', 'd'), 18),
#  (('c', 'yc'), 18),
#  (('q', 'c'), 18),
#  (('ep', 'pe'), 18),
#  (('lu', 'u'), 18),
#  (('y', 'hy'), 18),
#  (('', 'hy'), 18),
#  (('ay', 'y'), 17),
#  (('re', ''), 17),
#  (('l', 'e'), 17),
#  (('', 'ge'), 17),
#  (('s', 'd'), 17),
#  (('e', 'n'), 17),
#  (('u', 'lu'), 17),
#  (('di', 'i'), 17),
#  (('i', 'pi'), 17),
#  (('mo', 'o'), 17),
#  (('ht', 'th'), 17),
#  (('nd', 'n'), 17),
#  (('mo', 'om'), 17),
#  (('l', 'cl'), 17),
#  (('am', 'ma'), 17),
#  (('o', 'ot'), 17),
#  (('us', 'e'), 17),
#  (('dj', 'j'), 17),
#  (('r', 'gr'), 16),
#  (('d', 'e'), 16),
#  (('cs', 's'), 16),
#  (('r', 's'), 16),
#  (('ag', 'ga'), 16),
#  (('', 'en'), 16),
#  (('ue', 'eu'), 16),
#  (('rd', 'd'), 16),
#  (('oa', 'a'), 16),
#  (('d', 'ud'), 16),
#  (('', 've'), 16),
#  (('ce', 's'), 16),
#  (('ts', 's'), 16),
#  (('tu', 'u'), 16),
#  (('g', 'rg'), 16),
#  (('l', 'd'), 16),
#  (('v', 'nv'), 16),
#  (('pr', 'rp'), 16),
#  (('ty', ''), 16),
#  (('d', 'j'), 16),
#  (('i', 'ki'), 15),
#  (('h', 'n'), 15),
#  (('ep', 'p'), 15),
#  (('xc', 'c'), 15),
#  (("'t", 't'), 15),
#  (('ma', 'a'), 15),
#  (('k', 't'), 15),
#  (('e', 'ee'), 15),
#  (('k', 'h'), 15),
#  (('f', 'lf'), 15),
#  (('oi', 'io'), 15),
#  (('k', 'g'), 15),
#  (('n', 'd'), 15),
#  (('wr', 'r'), 15),
#  (('d', 'n'), 15),
#  (('iu', 'u'), 15),
#  (('v', 'av'), 15),
#  (('g', 'ig'), 15),
#  (('ns', 's'), 15),
#  (('id', 'di'), 15),
#  (('nt', 'n'), 15),
#  (('ls', 's'), 15),
#  (('', 'rs'), 15),
#  (('i', 'gi'), 15),
#  (('ur', 'ru'), 15),
#  (('h', 'gh'), 15),
#  (('ns', 'n'), 15),
#  (('', 'cs'), 15),
#  (('ae', 'e'), 15),
#  (('c', 'ch'), 15),
#  (('g', 'c'), 14),
#  (('k', 'ke'), 14),
#  (('ge', 'g'), 14),
#  (('mn', 'n'), 14),
#  (('o', 'so'), 14),
#  (('ts', 'st'), 14),
#  (('h', 't'), 14),
#  (('ca', 'ac'), 14),
#  (('on', 'no'), 14),
#  (('wl', 'l'), 14),
#  (("'", 'e'), 14),
#  (('ru', 'u'), 14),
#  (('s', 'ds'), 14),
#  (('r', 'p'), 14),
#  (('', 'se'), 14),
#  (('ce', ''), 14),
#  (('gi', 'i'), 14),
#  (('l', 'a'), 14),
#  (('le', ''), 14),
#  (('tl', 'l'), 14),
#  (('dm', 'm'), 14),
#  (('eh', 'he'), 14),
#  (('p', 'pe'), 14),
#  (('t', 'bt'), 14),
#  (('e', 'en'), 14),
#  (('no', 'o'), 14),
#  (('n', 'nt'), 14),
#  (('b', 'ib'), 13),
#  (('e', 'be'), 13),
#  (('n', 'nd'), 13),
#  (('ts', 't'), 13),
#  (('', 'ne'), 13),
#  (('ot', 't'), 13),
#  (('u', 'su'), 13),
#  (('n', 'pn'), 13),
#  (('j', 'dj'), 13),
#  (('r', 't'), 13),
#  (('mi', 'im'), 13),
#  (('t', 'r'), 13),
#  (('n', 'e'), 13),
#  (('n', 'l'), 13),
#  (('ic', 'c'), 13),
#  (('', 'th'), 13),
#  (('e', 'ly'), 13),
#  (('a', 'r'), 13),
#  (('cu', 'u'), 13),
#  (('rp', 'p'), 13),
#  (('he', 'h'), 13),
#  (('u', 'iu'), 13),
#  (('l', "'l"), 13),
#  (('ld', 'd'), 13),
#  (('s', 'i'), 13),
#  (('k', 'ks'), 13),
#  (('f', 'mf'), 13),
#  (('k', 'ok'), 12),
#  (('w', 'e'), 12),
#  (('m', 'ms'), 12),
#  (('a', 'l'), 12),
#  (('s', 'st'), 12),
#  (('sy', 'y'), 12),
#  (('j', 'g'), 12),
#  (('eg', 'ge'), 12),
#  (('ua', 'au'), 12),
#  (('c', 'uc'), 12),
#  (('ve', 'ev'), 12),
#  (('g', 'og'), 12),
#  (('l', 'rl'), 12),
#  (('ce', 't'), 12),
#  (('rg', 'g'), 12),
#  (('tr', 'r'), 12),
#  (('ge', 'e'), 12),
#  (('iu', 'ui'), 12),
#  (('ee', 'y'), 12),
#  (('r', 'd'), 12),
#  (('ht', 'h'), 12),
#  (('ow', 'o'), 12),
#  (('t', 'ce'), 12),
#  (('c', 'ce'), 12),
#  (('f', 'if'), 12),
#  (('ht', 't'), 12),
#  (('yl', 'ly'), 12),
#  (('s', 'x'), 12),
#  (('a', 'ar'), 12),
#  (('', 'id'), 12),
#  (('e', 'ey'), 12),
#  (('k', 'ak'), 12),
#  (('c', "'c"), 12),
#  (('be', 'e'), 12),
#  (('ev', 've'), 11),
#  (('rv', 'v'), 11),
#  (('a', 'ga'), 11),
#  (('l', '_l'), 11),
#  (('a', 'y'), 11),
#  (('h', 'e'), 11),
#  (('rb', 'b'), 11),
#  (('t', '_t'), 11),
#  (('po', 'op'), 11),
#  (('er', 'y'), 11),
#  (('go', 'o'), 11),
#  (('r', 'dr'), 11),
#  (('ab', 'b'), 11),
#  (('rt', 'tr'), 11),
#  (('qu', 'u'), 11),
#  (('q', 'eq'), 11),
#  (('p', 'f'), 11),
#  (('no', 'on'), 11),
#  (('te', ''), 11),
#  (('i', 'h'), 11),
#  (('u', 'nu'), 11),
#  (('ko', 'o'), 11),
#  (('e', 'ke'), 11),
#  (('c', 'x'), 11),
#  (('x', 'nx'), 11),
#  (('i', 'xi'), 11),
#  (('y', 'cy'), 11),
#  (('ke', 'k'), 11),
#  (('o', 'r'), 11),
#  (('c', 'cs'), 11),
#  (('o', 'wo'), 11),
#  (('rs', 'r'), 10),
#  (('c', 'o'), 10),
#  (('nv', 'v'), 10),
#  (('c', 'p'), 10),
#  (('h', 'ht'), 10),
#  (('nu', 'u'), 10),
#  (('', 'll'), 10),
#  (('e', 'b'), 10),
#  (('m', 'mb'), 10),
#  (('t', 'n'), 10),
#  (('di', 'id'), 10),
#  (('ye', 'y'), 10),
#  (('e', 'd'), 10),
#  (('yt', 't'), 10),
#  (('d', 'r'), 10),
#  (('hn', ''), 10),
#  (('gi', 'ig'), 10),
#  (('ao', 'o'), 10),
#  (('xs', 's'), 10),
#  (('cr', 'r'), 10),
#  (('', 'ut'), 10),
#  (('s', 'ys'), 10),
#  (('zi', 'i'), 10),
#  (('r', 'ry'), 10),
#  (('u', 'r'), 10),
#  (('l', 'ls'), 10),
#  (('ed', 't'), 10),
#  (('g', 'k'), 10),
#  (('ck', 'c'), 10),
#  (('tc', 'ct'), 10),
#  (('r', "'r"), 10),
#  (('y', 'ty'), 10),
#  (('gd', 'dg'), 10),
#  (('m', 'mn'), 10),
#  (('a', 'oa'), 10),
#  (('lm', 'm'), 10),
#  (('e', 'al'), 10),
#  (('ud', 'du'), 10),
#  (('u', 'du'), 10),
#  (('i', 'l'), 10),
#  (('n', 's'), 10),
#  (('io', 'oi'), 10),
#  (('ce', 'ec'), 10),
#  (('r', 'y'), 10),
#  (('', 'he'), 10),
#  (('', 'rn'), 10),
#  (('f', 'nf'), 10),
#  (('d', 'ds'), 10),
#  (('y', 'u'), 10),
#  (('cs', 'sc'), 10),
#  (('s', 'a'), 9),
#  (('um', ''), 9),
#  (('a', 's'), 9),
#  (('h', 's'), 9),
#  (('ty', 'y'), 9),
#  (('tt', 't'), 9),
#  (('ee', 'e'), 9),
#  (('om', 'mo'), 9),
#  (('ah', 'ha'), 9),
#  (('ys', 'y'), 9),
#  (('ct', 'tc'), 9),
#  (('ag', 'g'), 9),
#  (('t', 'k'), 9),
#  (('g', 'gs'), 9),
#  (('do', 'o'), 9),
#  (('g', 'eg'), 9),
#  (('oe', 'e'), 9),
#  (('_d', 'd'), 9),
#  (('eo', 'oe'), 9),
#  (('y', 'ys'), 9),
#  (('ys', 's'), 9),
#  (('t', 'th'), 9),
#  (('sa', 'as'), 9),
#  (('to', 'o'), 9),
#  (('k', 'nk'), 9),
#  (('fu', 'u'), 9),
#  (('l', 'u'), 9),
#  (('mu', 'um'), 9),
#  (('lw', 'w'), 9),
#  (('', 'gy'), 9),
#  (('ng', 'n'), 9),
#  (('ip', 'p'), 9),
#  (('a', 'd'), 9),
#  (('uc', 'cu'), 9),
#  (('kt', 't'), 9),
#  (('ec', 'ce'), 9),
#  (('n', 'g'), 9),
#  (('f', 've'), 9),
#  (('cp', 'p'), 9),
#  (('gh', ''), 9),
#  (('nl', 'l'), 9),
#  (('aq', 'q'), 9),
#  (('ey', 'e'), 9),
#  (('kq', 'q'), 9),
#  (('d', 'nt'), 9),
#  (('q', 'nq'), 9),
#  (('yr', 'r'), 8),
#  (('v', 'ov'), 8),
#  (('u', 'n'), 8),
#  (('e', 'm'), 8),
#  (('pt', 't'), 8),
#  (('p', 'xp'), 8),
#  (('_l', 'l'), 8),
#  (('oy', 'y'), 8),
#  (('ef', 'fe'), 8),
#  (('p', 'e'), 8),
#  (('ym', 'm'), 8),
#  (('uo', 'o'), 8),
#  (('ul', 'lu'), 8),
#  (('t', 'i'), 8),
#  (('en', ''), 8),
#  (('ds', 's'), 8),
#  (('o', 'l'), 8),
#  (('r', 'o'), 8),
#  (('wi', 'i'), 8),
#  (('y', 'o'), 8),
#  (('ig', 'gi'), 8),
#  (('-', '_'), 8),
#  (('a', 'da'), 8),
#  (('ot', 'to'), 8),
#  (('r', '-r'), 8),
#  (('ap', 'pa'), 8),
#  (('q', 'g'), 8),
#  (('oc', 'c'), 8),
#  (('sf', 'f'), 8),
#  (('e', 'ze'), 8),
#  (('l', 'b'), 8),
#  (('u', 'h'), 8),
#  (('gr', 'r'), 8),
#  (('e', "'"), 8),
#  (('', 'at'), 8),
#  (('eg', 'g'), 8),
#  (('', 'ur'), 8),
#  (('st', ''), 8),
#  (('pa', 'a'), 8),
#  (('ic', ''), 8),
#  (('za', 'a'), 8),
#  (('s', 'cs'), 8),
#  (('e', 'ye'), 8),
#  (('u', 'qu'), 8),
#  (('c', 'q'), 8),
#  (('h', 'he'), 8),
#  (('ht', ''), 8),
#  (('um', 'mu'), 8),
#  (('s', 'h'), 8),
#  (('', "'t"), 8),
#  (('m', 'e'), 8),
#  (('y', 'gy'), 8),
#  (('kr', 'r'), 8),
#  (('dl', 'ld'), 7),
#  (('oe', 'o'), 7),
#  (('ry', 'r'), 7),
#  (('y', 're'), 7),
#  (('es', 'y'), 7),
#  (('n', 'i'), 7),
#  (('ok', 'k'), 7),
#  (('ge', ''), 7),
#  (('m', 'b'), 7),
#  (('n', 'u'), 7),
#  (('tl', 'lt'), 7),
#  (('', 'st'), 7),
#  (('v', 'rv'), 7),
#  (('av', 'v'), 7),
#  (('y', 'ny'), 7),
#  (('d', 'c'), 7),
#  (('a', 'er'), 7),
#  (('d', 'ng'), 7),
#  (('ug', 'gu'), 7),
#  (('c', 'l'), 7),
#  (('ns', ''), 7),
#  (('t', 'm'), 7),
#  (('s', 'u'), 7),
#  (('ov', 'v'), 7),
#  (('wn', 'n'), 7),
#  (('e', 'us'), 7),
#  (('so', 'o'), 7),
#  (('we', 'e'), 7),
#  (('ny', 'y'), 7),
#  (('hc', 'ch'), 7),
#  (('e', 'w'), 7),
#  (('ka', 'ak'), 7),
#  (('ek', 'ke'), 7),
#  (('c', 'a'), 7),
#  (('gu', 'u'), 7),
#  (('b', 'hb'), 7),
#  (('c', 'n'), 7),
#  (('tu', 'ut'), 7),
#  (('a', 'n'), 7),
#  (('et', ''), 7),
#  (('ap', 'p'), 7),
#  (('s', 'ls'), 7),
#  (('-t', 't'), 7),
#  (('bi', 'i'), 7),
#  (('m', 'hm'), 7),
#  (('bl', 'l'), 7),
#  (('i', 't'), 7),
#  (('t', 'ft'), 7),
#  (('e', 'gh'), 7),
#  (('ts', ''), 7),
#  (('s', 'y'), 7),
#  (('f', 'gh'), 7),
#  (('oh', 'ho'), 7),
#  (('r', 'hr'), 7),
#  (('e', 'g'), 7),
#  (('i', 'oi'), 7),
#  (('mb', 'b'), 7),
#  (('t', 'y'), 7),
#  (('k', 'ch'), 7),
#  (('su', 'us'), 7),
#  (('su', 'u'), 7),
#  (('sl', 'l'), 7),
#  (('l', 'gl'), 7),
#  (("'n", "n'"), 7),
#  (('', 'rd'), 7),
#  (('c', '_c'), 7),
#  (('lp', 'p'), 7),
#  (('l', 'o'), 7),
#  (('da', 'a'), 7),
#  (('ct', 'c'), 7),
#  (('y', 'ir'), 7),
#  (('x', 's'), 7),
#  (('-r', 'r'), 7),
#  (('a', 'c'), 7),
#  (('ac', 'ca'), 7),
#  (('w', 'sw'), 7),
#  (('xf', 'f'), 7),
#  (('gd', 'd'), 7),
#  (('w', 'h'), 6),
#  (('u', 's'), 6),
#  (('kc', 'c'), 6),
#  (('ma', 'am'), 6),
#  (('e', 'is'), 6),
#  (('', 'oy'), 6),
#  (('l', 'w'), 6),
#  (('', 'ia'), 6),
#  (('st', 'ts'), 6),
#  (('', 'de'), 6),
#  (('iv', 'v'), 6),
#  (('dl', 'l'), 6),
#  (('f', 'l'), 6),
#  (('m', 'ym'), 6),
#  (('en', 'e'), 6),
#  (('n', 'o'), 6),
#  (('sm', 'm'), 6),
#  (('c', 'i'), 6),
#  (('_e', 'e'), 6),
#  (('rg', 'gr'), 6),
#  (('ip', 'pi'), 6),
#  (('gl', 'l'), 6),
#  (('u', 'ue'), 6),
#  (('w', 'r'), 6),
#  (('h', 'p'), 6),
#  (('d', 'te'), 6),
#  (('ye', 'e'), 6),
#  (('sr', 'rs'), 6),
#  (('t', 'ty'), 6),
#  (('ku', 'u'), 6),
#  (('lk', 'k'), 6),
#  (('i', 'r'), 6),
#  (('hw', 'wh'), 6),
#  (('b', '_b'), 6),
#  (('dt', 't'), 6),
#  (('hf', 'f'), 6),
#  (('a', 'fa'), 6),
#  (('ui', 'iu'), 6),
#  (('mn', 'm'), 6),
#  (('wo', 'ow'), 6),
#  (('i', 'wi'), 6),
#  (('r', 'h'), 6),
#  (('ea', 'ae'), 6),
#  (('oo', 'o'), 6),
#  (('ng', 'd'), 6),
#  (('pr', 'r'), 6),
#  (('e', 'c'), 6),
#  (('hs', 's'), 6),
#  (('', 'ef'), 6),
#  (('fe', 'ef'), 6),
#  (('fe', 'f'), 6),
#  (('if', 'fi'), 6),
#  (('', 'ls'), 6),
#  (('fi', 'if'), 6),
#  (('w', 'ew'), 6),
#  (('n', 'a'), 6),
#  (('ug', 'g'), 6),
#  (('', 'or'), 6),
#  (('we', 'ew'), 6),
#  (('cy', ''), 6),
#  (('se', ''), 6),
#  (('a', 'h'), 6),
#  (('h', 'sh'), 6),
#  (('b', 'v'), 6),
#  (('dv', 'v'), 6),
#  (('_v', 'v'), 6),
#  (('e', 'em'), 6),
#  (("'e", 'e'), 6),
#  (('re', 'y'), 6),
#  (('n', 'mn'), 6),
#  (('ne', ''), 6),
#  (('nu', 'un'), 6),
#  (('iq', 'q'), 6),
#  (('h', 'hs'), 6),
#  (('o', '_o'), 6),
#  (('ht', 'e'), 6),
#  (('l', 'n'), 6),
#  ...]

# %%
def P(word, N=sum(WORDS.values())):
    return (WORDS[word]+0.5) / (N + 0.5*len(WORDS))

def likelihood(typo, correct):
    if agg_by_mistake[typo] != 0:
        return(mistake_count[(typo, correct)]/(agg_by_mistake[typo]))
    else:
        return(1e-5)
def posterior(correct_word, mispelled_words):
    mistake = difference_of_words(correct_word, mispelled_words)
    return(P(correct_word)*likelihood(mistake['error'], mistake['true']))

# %%
def candidates(mispelled_word, max_distance = 2):
    if max_distance == 1:
        candidates = known(edits1(mispelled_word)) or [word]
    elif max_distance == 2:
        candidates = known(edits1(mispelled_word)) or known(edits2(mispelled_word)) or [word]
    candidate_dict = dict()
    for candidate in candidates:
        candidate_dict[candidate] = posterior(candidate, mispelled_word)
    normalizing_constant = sum(candidate_dict.values())
    candidate_dict = {k:v/normalizing_constant for k,v in candidate_dict.items()}
    return(candidate_dict)

# %%
sorted(candidates("acress").items(), key=lambda x: x[1], reverse = True)
# Out:
# [('acres', 0.5885981563154824),
#  ('across', 0.38995802755760417),
#  ('caress', 0.008584594114772063),
#  ('actress', 0.006520761434728196),
#  ('access', 0.006338460577413214)]

# %%
def correction(mispelled_word):
    _candidates = candidates(mispelled_word)
    return(max(_candidates, key=_candidates.get))

# %%
candidates('proces')
# Out:
# {'prices': 0.24503567098414214,
#  'process': 0.7510410410986045,
#  'proves': 0.003923287917253451}

# %% [markdown]
# ### Pruebas

# %%
def spelltest(tests, verbose=False):
    "Run correction(wrong) on all (right, wrong) pairs; report results."
    import time
    start = time.clock()
    good, unknown = 0, 0
    n = 0
    for right, wrong in tests:
        if (wrong not in WORDS)&(right in WORDS):
            n += 1
            w = correction(wrong)
            good += (w == right)
            if w != right:
                unknown += (right not in WORDS)
                if verbose:
                    print('correction({}) => {} ({}); expected {} ({})'
                          .format(wrong, w, WORDS[w], right, WORDS[right]))
    dt = time.clock() - start
    print('{:.0%} of {} at {:.0f} words per second '
          .format(good / n, n, n / dt))

def Testset(lines):
    "Parse 'right: wrong1 wrong2' lines into [('right', 'wrong1'), ('right', 'wrong2')] pairs."
    return [(right, wrong)
            for (right, wrongs) in (line.split(':') for line in lines)
            for wrong in wrongs.split()]

# %%
spelltest(Testset(open('data/spell-testset1.txt')))
# Out:
# 83% of 252 at 48 words per second

# %% [markdown]
# ## Factores adicionales que se pueden incluir en el modelo
# - Palabras adyacentes
# - Errores personalizados del usuario
